# %% [markdown]
# <a href="https://colab.research.google.com/github/AJ0043/advance-ai-job-portal/blob/main/Job_portal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings

# %%
job_title = pd.read_csv("/content/ai_job_dataset-selected-columns.csv")
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title.head(100)
# Out:
#      job_id                    job_title  salary_usd salary_currency  \
# 0   AI00001        AI Research Scientist       90376             USD
# 1   AI00002         AI Software Engineer       61895             USD
# 2   AI00003                AI Specialist      152626             USD
# 3   AI00004                 NLP Engineer       80215             USD
# 4   AI00005                AI Consultant       54624             EUR
# ..      ...                          ...         ...             ...
# 95  AI00096                 NLP Engineer       98688             USD
# 96  AI00097                 Data Analyst      109029             EUR
# 97  AI00098                 NLP Engineer       84797             USD
# 98  AI00099  Machine Learning Researcher      290199             USD
# 99  AI00100        AI Research Scientist      195691             USD
#
#    experience_level employment_type company_location company_size  \
# 0                SE              CT            China            M
# 1                EN              CT           Canada            M
# 2                MI              FL      Switzerland            L
# 3                SE              FL            India            M
# 4                EN              PT           France            S
# ..              ...             ...              ...          ...
# 95               SE              FT           Israel            M
# 96               SE              FT           France            S
# 97               MI              FT           Canada            M
# 98               EX              CT      Switzerland            L
# 99               SE              CT    United States            L
#
#    employee_residence  remote_ratio
# 0               China            50
# 1             Ireland           100
# 2         South Korea             0
# 3               India            50
# 4           Singapore           100
# ..                ...           ...
# 95             Israel            50
# 96             France             0
# 97             Canada             0
# 98            Denmark            50
# 99      United States             0
#
# [100 rows x 10 columns]

# %%
job_title.shape
# Out:
# (15000, 10)

# %%
job_title.columns
# Out:
# Index(['job_id', 'job_title', 'salary_usd', 'salary_currency',
#        'experience_level', 'employment_type', 'company_location',
#        'company_size', 'employee_residence', 'remote_ratio'],
#       dtype='object')

# %%
job_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_id              15000 non-null  object
#  1   job_title           15000 non-null  object
#  2   salary_usd          15000 non-null  int64
#  3   salary_currency     15000 non-null  object
#  4   experience_level    15000 non-null  object
#  5   employment_type     15000 non-null  object
#  6   company_location    15000 non-null  object
#  7   company_size        15000 non-null  object
#  8   employee_residence  15000 non-null  object
#  9   remote_ratio        15000 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 1.1+ MB

# %%
job_title.describe()
# Out:
#           salary_usd  remote_ratio
# count   15000.000000  15000.000000
# mean   115348.965133     49.483333
# std     60260.940438     40.812712
# min     32519.000000      0.000000
# 25%     70179.750000      0.000000
# 50%     99705.000000     50.000000
# 75%    146408.500000    100.000000
# max    399095.000000    100.000000

# %%
job_title.isnull().sum()
# Out:
# job_id                0
# job_title             0
# salary_usd            0
# salary_currency       0
# experience_level      0
# employment_type       0
# company_location      0
# company_size          0
# employee_residence    0
# remote_ratio          0
# dtype: int64

# %%
job_title.duplicated().sum()
# Out:
# np.int64(0)

# %%
job_title = job_title.drop_duplicates()
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['job_title'].value_counts()
# Out:
# job_title
# Machine Learning Researcher    808
# AI Software Engineer           784
# Autonomous Systems Engineer    777
# Machine Learning Engineer      772
# AI Architect                   771
# Head of AI                     765
# NLP Engineer                   762
# Robotics Engineer              759
# Data Analyst                   759
# AI Research Scientist          756
# Data Engineer                  749
# AI Product Manager             743
# Research Scientist             742
# Principal Data Scientist       734
# AI Specialist                  728
# ML Ops Engineer                725
# Computer Vision Engineer       724
# Data Scientist                 720
# Deep Learning Engineer         718
# AI Consultant                  704
# Name: count, dtype: int64

# %%
job_title['experience_level'].value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
job_title['employment_type'].value_counts()
# Out:
# employment_type
# FT    3812
# FL    3758
# CT    3721
# PT    3709
# Name: count, dtype: int64

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

job_title['job_title'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
job_title.rename(columns = {'USD':"US Doller"},inplace=True)

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
#job_title['salary_currency'] = job_title['salary_currency'].replace({
 #   'USD': 'Dollar',
 ##   'EUR': 'Euro'
#})

# %%
job_title['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    11957
# EUR     2314
# GBP      729
# Name: count, dtype: int64

# %%
job_title['salary_currency'] = job_title['salary_currency'].replace({
    'USD': 'Dollar',
    'EUR': 'EURO DOller',
    'GBP': 'Great Britesh Pound'


})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 0      AI00001        AI Research Scientist       90376               Dollar
# 1      AI00002         AI Software Engineer       61895               Dollar
# 2      AI00003                AI Specialist      152626               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 4      AI00005                AI Consultant       54624          EURO DOller
# ...        ...                          ...         ...                  ...
# 14995  AI14996            Robotics Engineer       38604               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
# 14997  AI14998                 NLP Engineer      189490               Dollar
# 14998  AI14999                   Head of AI       79461          EURO DOller
# 14999  AI15000     Computer Vision Engineer       56481               Dollar
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
#job_title['salary_currency'].value_counts()
job_title['experience_level'].value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
job_title['experience_level']=job_title['experience_level'].replace=({
    "SE":'Senior level',
    'EN':'Entry level',
    'MI	': 'Mid level',
    'EX': 'Executive level'
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 0      AI00001        AI Research Scientist       90376               Dollar
# 1      AI00002         AI Software Engineer       61895               Dollar
# 2      AI00003                AI Specialist      152626               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 4      AI00005                AI Consultant       54624          EURO DOller
# ...        ...                          ...         ...                  ...
# 14995  AI14996            Robotics Engineer       38604               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
# 14997  AI14998                 NLP Engineer      189490               Dollar
# 14998  AI14999                   Head of AI       79461          EURO DOller
# 14999  AI15000     Computer Vision Engineer       56481               Dollar
#
#       experience_level employment_type company_location company_size  \
# 0                  NaN        Contract            China            M
# 1                  NaN        Contract           Canada            M
# 2                  NaN       Freelance      Switzerland            L
# 3                  NaN       Freelance            India            M
# 4                  NaN       Part Time           France            S
# ...                ...             ...              ...          ...
# 14995              NaN       Freelance          Finland            S
# 14996              NaN        Contract   United Kingdom            M
# 14997              NaN        Contract      South Korea            L
# 14998              NaN       Full-Time      Netherlands            M
# 14999              NaN       Part Time          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['employment_type'].value_counts()
# Out:
# employment_type
# FT    3812
# FL    3758
# CT    3721
# PT    3709
# Name: count, dtype: int64

# %%
job_title['employment_type'].replace({
    'FT': 'Full-Time',
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part Time'
}, inplace=True)

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 0      AI00001        AI Research Scientist       90376               Dollar
# 1      AI00002         AI Software Engineer       61895               Dollar
# 2      AI00003                AI Specialist      152626               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 4      AI00005                AI Consultant       54624          EURO DOller
# ...        ...                          ...         ...                  ...
# 14995  AI14996            Robotics Engineer       38604               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
# 14997  AI14998                 NLP Engineer      189490               Dollar
# 14998  AI14999                   Head of AI       79461          EURO DOller
# 14999  AI15000     Computer Vision Engineer       56481               Dollar
#
#       experience_level employment_type company_location company_size  \
# 0                  NaN        Contract            China            M
# 1                  NaN        Contract           Canada            M
# 2                  NaN       Freelance      Switzerland            L
# 3                  NaN       Freelance            India            M
# 4                  NaN       Part Time           France            S
# ...                ...             ...              ...          ...
# 14995              NaN       Freelance          Finland            S
# 14996              NaN        Contract   United Kingdom            M
# 14997              NaN        Contract      South Korea            L
# 14998              NaN       Full-Time      Netherlands            M
# 14999              NaN       Part Time          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['experice'].replace({
    'FT': 'Full-Time',
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part Time'
}, inplace=True)

# %%
job_title['experience_level'].unique()
# Out:
# array([nan], dtype=object)

# %%
job_title = job_title_backup.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2222/2457037061.py in <cell line: 0>()
# ----> 1 job_title = job_title_backup.copy()
#
# NameError: name 'job_title_backup' is not defined

# %%
job_title = pd.read_csv("/content/ai_job_dataset-selected-columns.csv")

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# 0                   SE              CT            China            M
# 1                   EN              CT           Canada            M
# 2                   MI              FL      Switzerland            L
# 3                   SE              FL            India            M
# 4                   EN              PT           France            S
# ...                ...             ...              ...          ...
# 14995               EN              FL          Finland            S
# 14996               EN              CT   United Kingdom            M
# 14997               EX              CT      South Korea            L
# 14998               EN              FT      Netherlands            M
# 14999               MI              PT          Austria            S
#
#       employee_residence  remote_ratio
# 0                  China            50
# 1                Ireland           100
# 2            South Korea             0
# 3                  India            50
# 4              Singapore           100
# ...                  ...           ...
# 14995            Finland            50
# 14996     United Kingdom             0
# 14997        South Korea            50
# 14998        Netherlands             0
# 14999            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['salary_currency']=job_title['salary_currency'].replace({
    'USD':'US-Doller(USD)',
    'EUR':'Euros(EUR)',
    'GBP':'Great Britesh Pound(GBP)',
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)               SE              CT
# 1                US-Doller(USD)               EN              CT
# 2                US-Doller(USD)               MI              FL
# 3                US-Doller(USD)               SE              FL
# 4                    Euros(EUR)               EN              PT
# ...                         ...              ...             ...
# 14995            US-Doller(USD)               EN              FL
# 14996  Great Britesh Pound(GBP)               EN              CT
# 14997            US-Doller(USD)               EX              CT
# 14998                Euros(EUR)               EN              FT
# 14999            US-Doller(USD)               MI              PT
#
#       company_location company_size employee_residence  remote_ratio
# 0                China            M              China            50
# 1               Canada            M            Ireland           100
# 2          Switzerland            L        South Korea             0
# 3                India            M              India            50
# 4               France            S          Singapore           100
# ...                ...          ...                ...           ...
# 14995          Finland            S            Finland            50
# 14996   United Kingdom            M     United Kingdom             0
# 14997      South Korea            L        South Korea            50
# 14998      Netherlands            M        Netherlands             0
# 14999          Austria            S            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title_backup = job_title.copy()

# %%
job_title_backup
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)               SE              CT
# 1                US-Doller(USD)               EN              CT
# 2                US-Doller(USD)               MI              FL
# 3                US-Doller(USD)               SE              FL
# 4                    Euros(EUR)               EN              PT
# ...                         ...              ...             ...
# 14995            US-Doller(USD)               EN              FL
# 14996  Great Britesh Pound(GBP)               EN              CT
# 14997            US-Doller(USD)               EX              CT
# 14998                Euros(EUR)               EN              FT
# 14999            US-Doller(USD)               MI              PT
#
#       company_location company_size employee_residence  remote_ratio
# 0                China            M              China            50
# 1               Canada            M            Ireland           100
# 2          Switzerland            L        South Korea             0
# 3                India            M              India            50
# 4               France            S          Singapore           100
# ...                ...          ...                ...           ...
# 14995          Finland            S            Finland            50
# 14996   United Kingdom            M     United Kingdom             0
# 14997      South Korea            L        South Korea            50
# 14998      Netherlands            M        Netherlands             0
# 14999          Austria            S            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['experience_level']=job_title['experience_level'].replace({
    'US-Doller(USD)': 'Entry level',
    'Euros(EUR)': 'Senior level',
    'Great Britesh Pound(GBP)': 'middle level',
    'EX': 'Excecutive levels'

})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)      Entry level              CT
# 1                US-Doller(USD)      Entry level              CT
# 2                US-Doller(USD)      Entry level              FL
# 3                US-Doller(USD)      Entry level              FL
# 4                    Euros(EUR)     Senior level              PT
# ...                         ...              ...             ...
# 14995            US-Doller(USD)      Entry level              FL
# 14996  Great Britesh Pound(GBP)     middle level              CT
# 14997            US-Doller(USD)      Entry level              CT
# 14998                Euros(EUR)     Senior level              FT
# 14999            US-Doller(USD)      Entry level              PT
#
#       company_location company_size employee_residence  remote_ratio
# 0                China            M              China            50
# 1               Canada            M            Ireland           100
# 2          Switzerland            L        South Korea             0
# 3                India            M              India            50
# 4               France            S          Singapore           100
# ...                ...          ...                ...           ...
# 14995          Finland            S            Finland            50
# 14996   United Kingdom            M     United Kingdom             0
# 14997      South Korea            L        South Korea            50
# 14998      Netherlands            M        Netherlands             0
# 14999          Austria            S            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title_backup = job_title.copy()

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)      Entry level              CT
# 1                US-Doller(USD)      Entry level              CT
# 2                US-Doller(USD)      Entry level              FL
# 3                US-Doller(USD)      Entry level              FL
# 4                    Euros(EUR)     Senior level              PT
# ...                         ...              ...             ...
# 14995            US-Doller(USD)      Entry level              FL
# 14996  Great Britesh Pound(GBP)     middle level              CT
# 14997            US-Doller(USD)      Entry level              CT
# 14998                Euros(EUR)     Senior level              FT
# 14999            US-Doller(USD)      Entry level              PT
#
#       company_location company_size employee_residence  remote_ratio
# 0                China            M              China            50
# 1               Canada            M            Ireland           100
# 2          Switzerland            L        South Korea             0
# 3                India            M              India            50
# 4               France            S          Singapore           100
# ...                ...          ...                ...           ...
# 14995          Finland            S            Finland            50
# 14996   United Kingdom            M     United Kingdom             0
# 14997      South Korea            L        South Korea            50
# 14998      Netherlands            M        Netherlands             0
# 14999          Austria            S            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['employment_type'] = job_title['employment_type'].replace({
    'FT': 'Full-Time',
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part Time'
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)      Entry level        Contract
# 1                US-Doller(USD)      Entry level        Contract
# 2                US-Doller(USD)      Entry level       Freelance
# 3                US-Doller(USD)      Entry level       Freelance
# 4                    Euros(EUR)     Senior level       Part Time
# ...                         ...              ...             ...
# 14995            US-Doller(USD)      Entry level       Freelance
# 14996  Great Britesh Pound(GBP)     middle level        Contract
# 14997            US-Doller(USD)      Entry level        Contract
# 14998                Euros(EUR)     Senior level       Full-Time
# 14999            US-Doller(USD)      Entry level       Part Time
#
#       company_location company_size employee_residence  remote_ratio
# 0                China            M              China            50
# 1               Canada            M            Ireland           100
# 2          Switzerland            L        South Korea             0
# 3                India            M              India            50
# 4               France            S          Singapore           100
# ...                ...          ...                ...           ...
# 14995          Finland            S            Finland            50
# 14996   United Kingdom            M     United Kingdom             0
# 14997      South Korea            L        South Korea            50
# 14998      Netherlands            M        Netherlands             0
# 14999          Austria            S            Austria            50
#
# [15000 rows x 10 columns]

# %%
job_title['company_size']=job_title['company_size'].replace({
    'M': 'multi-national company',
    'L': 'Large Company',
    'S':  'Small company'
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)      Entry level        Contract
# 1                US-Doller(USD)      Entry level        Contract
# 2                US-Doller(USD)      Entry level       Freelance
# 3                US-Doller(USD)      Entry level       Freelance
# 4                    Euros(EUR)     Senior level       Part Time
# ...                         ...              ...             ...
# 14995            US-Doller(USD)      Entry level       Freelance
# 14996  Great Britesh Pound(GBP)     middle level        Contract
# 14997            US-Doller(USD)      Entry level        Contract
# 14998                Euros(EUR)     Senior level       Full-Time
# 14999            US-Doller(USD)      Entry level       Part Time
#
#       company_location            company_size employee_residence  \
# 0                China  multi-national company              China
# 1               Canada  multi-national company            Ireland
# 2          Switzerland           Large Company        South Korea
# 3                India  multi-national company              India
# 4               France           Small company          Singapore
# ...                ...                     ...                ...
# 14995          Finland           Small company            Finland
# 14996   United Kingdom  multi-national company     United Kingdom
# 14997      South Korea           Large Company        South Korea
# 14998      Netherlands  multi-national company        Netherlands
# 14999          Austria           Small company            Austria
#
#        remote_ratio
# 0                50
# 1               100
# 2                 0
# 3                50
# 4               100
# ...             ...
# 14995            50
# 14996             0
# 14997            50
# 14998             0
# 14999            50
#
# [15000 rows x 10 columns]

# %%
job_title[job_title['company_location']=='India'].shape[0]
# Out:
# 754

# %%
#india_jobs = job_title[job_title['company_location'] == 'India']
#india_jobs
india_jobs = job_title[job_title['company_location']=='India']
india_jobs
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio
# 3      multi-national company              India            50
# 16              Large Company              India           100
# 46              Small company              India            50
# 51     multi-national company              India           100
# 56              Large Company              India           100
# ...                       ...                ...           ...
# 14922           Small company              India            50
# 14938  multi-national company        South Korea             0
# 14947           Small company              India             0
# 14951           Small company              India             0
# 14965           Small company        Netherlands             0
#
# [754 rows x 10 columns]

# %%
cities = ['Noida', 'Hyderabad', 'Bangalore', 'Pune', 'Mumbai', 'Jaipur', 'Indore']

job_title['City'] = np.random.choice(cities, size=len(job_title))

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)      Entry level        Contract
# 1                US-Doller(USD)      Entry level        Contract
# 2                US-Doller(USD)      Entry level       Freelance
# 3                US-Doller(USD)      Entry level       Freelance
# 4                    Euros(EUR)     Senior level       Part Time
# ...                         ...              ...             ...
# 14995            US-Doller(USD)      Entry level       Freelance
# 14996  Great Britesh Pound(GBP)     middle level        Contract
# 14997            US-Doller(USD)      Entry level        Contract
# 14998                Euros(EUR)     Senior level       Full-Time
# 14999            US-Doller(USD)      Entry level       Part Time
#
#       company_location            company_size employee_residence  \
# 0                China  multi-national company              China
# 1               Canada  multi-national company            Ireland
# 2          Switzerland           Large Company        South Korea
# 3                India  multi-national company              India
# 4               France           Small company          Singapore
# ...                ...                     ...                ...
# 14995          Finland           Small company            Finland
# 14996   United Kingdom  multi-national company     United Kingdom
# 14997      South Korea           Large Company        South Korea
# 14998      Netherlands  multi-national company        Netherlands
# 14999          Austria           Small company            Austria
#
#        remote_ratio       City
# 0                50     Jaipur
# 1               100     Mumbai
# 2                 0     Mumbai
# 3                50  Hyderabad
# 4               100     Indore
# ...             ...        ...
# 14995            50      Noida
# 14996             0     Jaipur
# 14997            50     Indore
# 14998             0     Indore
# 14999            50     Jaipur
#
# [15000 rows x 11 columns]

# %%
job_title['company_location'].value_counts()
# Out:
# company_location
# Germany           814
# Denmark           778
# Canada            769
# France            769
# Austria           765
# Singapore         764
# China             763
# India             754
# Sweden            752
# Israel            751
# Ireland           750
# Switzerland       746
# Japan             733
# Finland           733
# Australia         732
# Netherlands       731
# United Kingdom    729
# United States     724
# South Korea       722
# Norway            721
# Name: count, dtype: int64

# %%
# I choose Some Countries #
countries = ['India', 'Norway', 'Canada', 'United States',
             'United Kingdom', 'Japan', 'Singapore']

job_title2 = job_title[job_title['company_location'].isin(countries)].copy()

# %%
# New Table Genrate #
job_title2
# Out:
#         job_id                    job_title  salary_usd  \
# 1      AI00002         AI Software Engineer       61895
# 3      AI00004                 NLP Engineer       80215
# 6      AI00007     Principal Data Scientist       79670
# 8      AI00009                 Data Analyst      160710
# 13     AI00014  Autonomous Systems Engineer       68760
# ...        ...                          ...         ...
# 14982  AI14983                 Data Analyst       70721
# 14983  AI14984                 AI Architect      288661
# 14984  AI14985               Data Scientist      138888
# 14991  AI14992            Robotics Engineer       97480
# 14996  AI14997  Machine Learning Researcher       57811
#
#                 salary_currency experience_level employment_type  \
# 1                US-Doller(USD)      Entry level        Contract
# 3                US-Doller(USD)      Entry level       Freelance
# 6      Great Britesh Pound(GBP)     middle level       Freelance
# 8                US-Doller(USD)      Entry level        Contract
# 13               US-Doller(USD)      Entry level        Contract
# ...                         ...              ...             ...
# 14982            US-Doller(USD)      Entry level       Freelance
# 14983            US-Doller(USD)      Entry level       Freelance
# 14984            US-Doller(USD)      Entry level       Full-Time
# 14991            US-Doller(USD)      Entry level       Full-Time
# 14996  Great Britesh Pound(GBP)     middle level        Contract
#
#       company_location            company_size employee_residence  \
# 1               Canada  multi-national company            Ireland
# 3                India  multi-national company              India
# 6       United Kingdom           Small company     United Kingdom
# 8            Singapore           Large Company          Singapore
# 13              Norway           Small company             Norway
# ...                ...                     ...                ...
# 14982           Norway           Small company          Australia
# 14983    United States           Large Company     United Kingdom
# 14984            Japan  multi-national company            Austria
# 14991    United States  multi-national company      United States
# 14996   United Kingdom  multi-national company     United Kingdom
#
#        remote_ratio       City
# 1               100     Mumbai
# 3                50  Hyderabad
# 6                 0     Jaipur
# 8                 0      Noida
# 13                0      Noida
# ...             ...        ...
# 14982             0     Mumbai
# 14983           100  Bangalore
# 14984           100     Indore
# 14991            50     Jaipur
# 14996             0     Jaipur
#
# [5194 rows x 11 columns]

# %%
# dlete city column
job_title2.drop('City',axis=1,inplace=True)
job_title2
# Out:
#         job_id                    job_title  salary_usd  \
# 1      AI00002         AI Software Engineer       61895
# 3      AI00004                 NLP Engineer       80215
# 6      AI00007     Principal Data Scientist       79670
# 8      AI00009                 Data Analyst      160710
# 13     AI00014  Autonomous Systems Engineer       68760
# ...        ...                          ...         ...
# 14982  AI14983                 Data Analyst       70721
# 14983  AI14984                 AI Architect      288661
# 14984  AI14985               Data Scientist      138888
# 14991  AI14992            Robotics Engineer       97480
# 14996  AI14997  Machine Learning Researcher       57811
#
#                 salary_currency experience_level employment_type  \
# 1                US-Doller(USD)      Entry level        Contract
# 3                US-Doller(USD)      Entry level       Freelance
# 6      Great Britesh Pound(GBP)     middle level       Freelance
# 8                US-Doller(USD)      Entry level        Contract
# 13               US-Doller(USD)      Entry level        Contract
# ...                         ...              ...             ...
# 14982            US-Doller(USD)      Entry level       Freelance
# 14983            US-Doller(USD)      Entry level       Freelance
# 14984            US-Doller(USD)      Entry level       Full-Time
# 14991            US-Doller(USD)      Entry level       Full-Time
# 14996  Great Britesh Pound(GBP)     middle level        Contract
#
#       company_location            company_size employee_residence  \
# 1               Canada  multi-national company            Ireland
# 3                India  multi-national company              India
# 6       United Kingdom           Small company     United Kingdom
# 8            Singapore           Large Company          Singapore
# 13              Norway           Small company             Norway
# ...                ...                     ...                ...
# 14982           Norway           Small company          Australia
# 14983    United States           Large Company     United Kingdom
# 14984            Japan  multi-national company            Austria
# 14991    United States  multi-national company      United States
# 14996   United Kingdom  multi-national company     United Kingdom
#
#        remote_ratio
# 1               100
# 3                50
# 6                 0
# 8                 0
# 13                0
# ...             ...
# 14982             0
# 14983           100
# 14984           100
# 14991            50
# 14996             0
#
# [5194 rows x 10 columns]

# %%
 india_df = job_title[job_title['company_location'] == 'India'].copy()
india_df.head(100)
# Out:
#        job_id                    job_title  salary_usd salary_currency  \
# 3     AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16    AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46    AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51    AI00052           Research Scientist      115376  US-Doller(USD)
# 56    AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...       ...                          ...         ...             ...
# 2060  AI02061                AI Consultant       57535  US-Doller(USD)
# 2078  AI02079              ML Ops Engineer       43469  US-Doller(USD)
# 2091  AI02092                 AI Architect       85133  US-Doller(USD)
# 2098  AI02099                Data Engineer       63425  US-Doller(USD)
# 2099  AI02100       Deep Learning Engineer       42742  US-Doller(USD)
#
#      experience_level employment_type company_location  \
# 3         Entry level       Freelance            India
# 16        Entry level       Full-Time            India
# 46        Entry level        Contract            India
# 51        Entry level       Full-Time            India
# 56        Entry level       Freelance            India
# ...               ...             ...              ...
# 2060      Entry level       Full-Time            India
# 2078      Entry level        Contract            India
# 2091      Entry level       Part Time            India
# 2098      Entry level        Contract            India
# 2099      Entry level       Full-Time            India
#
#                 company_size employee_residence  remote_ratio       City
# 3     multi-national company              India            50  Hyderabad
# 16             Large Company              India           100  Hyderabad
# 46             Small company              India            50     Mumbai
# 51    multi-national company              India           100     Indore
# 56             Large Company              India           100      Noida
# ...                      ...                ...           ...        ...
# 2060           Large Company              India            50     Indore
# 2078           Large Company              India           100       Pune
# 2091           Small company            Denmark           100       Pune
# 2098           Small company     United Kingdom            50     Mumbai
# 2099           Large Company              India            50       Pune
#
# [100 rows x 11 columns]

# %%
india_df['Company_Name'] = ""
india_df['Email'] = ""
india_df['Company_cities'] = ""

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities
# 3
# 16
# 46
# 51
# 56
# ...            ...   ...            ...
# 14922
# 14938
# 14947
# 14951
# 14965
#
# [754 rows x 14 columns]

# %%
india_df['Company_status'] = ""

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities Company_status
# 3
# 16
# 46
# 51
# 56
# ...            ...   ...            ...            ...
# 14922
# 14938
# 14947
# 14951
# 14965
#
# [754 rows x 15 columns]

# %%
company_types = [
    'Fintech',
    'Small Company',
    'Large Company',
    'Unicorn',
    'MNC',
    'Startup',
    'Product Based',
    'Featured Company'
]

import numpy as np

india_df['company_type'] = np.random.choice(company_types, size=len(india_df))

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities Company_status      company_type
# 3                                                                Startup
# 16                                                               Fintech
# 46                                                         Large Company
# 51                                                               Startup
# 56                                                                   MNC
# ...            ...   ...            ...            ...               ...
# 14922                                                            Unicorn
# 14938                                                   Featured Company
# 14947                                                      Small Company
# 14951                                                            Startup
# 14965                                                      Product Based
#
# [754 rows x 16 columns]

# %%
city_based_types = {
    'Hyderabad': ['Fintech', 'MNC', 'Startup'],
    'Mumbai': ['Large Company', 'MNC', 'Featured Company'],
    'Pune': ['Startup', 'Product Based'],
    'Noida': ['Fintech', 'Startup'],
    'Bangalore': ['Unicorn', 'Product Based', 'Startup'],
    'Indore': ['Small Company', 'Startup']
}

def assign_company_type(city):
    return np.random.choice(city_based_types.get(city, company_types))

india_df['company_type'] = india_df['City'].apply(assign_company_type)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities Company_status      company_type
# 3                                                                Startup
# 16                                                               Fintech
# 46                                                      Featured Company
# 51                                                               Startup
# 56                                                               Fintech
# ...            ...   ...            ...            ...               ...
# 14922                                                   Featured Company
# 14938                                                                MNC
# 14947                                                            Startup
# 14951                                                            Startup
# 14965                                                   Featured Company
#
# [754 rows x 16 columns]

# %%
# city in hydrabd
hyd_df = india_df[india_df['City'] == 'Hyderabad'].copy()
hyd_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 562    AI00563           Research Scientist       62692  US-Doller(USD)
# 615    AI00616                 AI Architect       65919  US-Doller(USD)
# 618    AI00619            Robotics Engineer      115496  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14146  AI14147  Autonomous Systems Engineer       61327  US-Doller(USD)
# 14153  AI14154  Machine Learning Researcher       64702  US-Doller(USD)
# 14438  AI14439              ML Ops Engineer      170461  US-Doller(USD)
# 14600  AI14601         AI Software Engineer      124455  US-Doller(USD)
# 14741  AI14742  Machine Learning Researcher       47320  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 562        Entry level       Part Time            India
# 615        Entry level       Full-Time            India
# 618        Entry level        Contract            India
# ...                ...             ...              ...
# 14146      Entry level        Contract            India
# 14153      Entry level       Part Time            India
# 14438      Entry level       Full-Time            India
# 14600      Entry level       Freelance            India
# 14741      Entry level       Full-Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 562    multi-national company              India             0  Hyderabad
# 615             Small company              India            50  Hyderabad
# 618             Large Company              India           100  Hyderabad
# ...                       ...                ...           ...        ...
# 14146           Large Company              Japan            50  Hyderabad
# 14153           Large Company              India           100  Hyderabad
# 14438  multi-national company              India            50  Hyderabad
# 14600           Small company              India            50  Hyderabad
# 14741  multi-national company          Singapore            50  Hyderabad
#
#       Company_Name Email Company_cities Company_status company_type
# 3                                                           Startup
# 16                                                          Fintech
# 562                                                         Fintech
# 615                                                         Fintech
# 618                                                             MNC
# ...            ...   ...            ...            ...          ...
# 14146                                                           MNC
# 14153                                                       Fintech
# 14438                                                       Startup
# 14600                                                           MNC
# 14741                                                       Startup
#
# [106 rows x 16 columns]

# %%
# Make a Comman list in the india_df
fintech_companies = ['Navi Technologies', 'Tide', 'Rupeek', 'PhonePe']
mnc_companies = ['Western Union', 'Capgemini', 'BMC Software']
product_companies = ['Qualiyze', 'Onetrust', 'Nucleus Software']
top_companies = ['Tata Nexarc', 'Justdial', 'Optum']

all_companies = fintech_companies + mnc_companies + product_companies + top_companies

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities Company_status      company_type
# 3                                                                Startup
# 16                                                               Fintech
# 46                                                      Featured Company
# 51                                                               Startup
# 56                                                               Fintech
# ...            ...   ...            ...            ...               ...
# 14922                                                   Featured Company
# 14938                                                                MNC
# 14947                                                            Startup
# 14951                                                            Startup
# 14965                                                   Featured Company
#
# [754 rows x 16 columns]

# %%
# Comapny Name
india_df['Company_Name'] = np.random.choice(all_companies, size=len(india_df))

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#            Company_Name Email Company_cities Company_status      company_type
# 3          BMC Software                                               Startup
# 16             Onetrust                                               Fintech
# 46            Capgemini                                      Featured Company
# 51              PhonePe                                               Startup
# 56             Onetrust                                               Fintech
# ...                 ...   ...            ...            ...               ...
# 14922          Qualiyze                                      Featured Company
# 14938  Nucleus Software                                                   MNC
# 14947            Rupeek                                               Startup
# 14951           PhonePe                                               Startup
# 14965  Nucleus Software                                      Featured Company
#
# [754 rows x 16 columns]

# %%
# Hyderabad wali rows filter
hyd_mask = india_df['City'] == 'Hyderabad'

# Hyderabad companies list
hyd_companies = ['Navi Technologies', 'Tide', 'Rupeek', 'PhonePe',
                 'Western Union', 'Capgemini', 'BMC Software',
                 'Qualyze', 'Onetrust', 'Nucleus Software',
                 'Tata Nexarc', 'Justdial', 'Optum']

# Sirf Hyderabad rows me assign karo
india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(
    hyd_companies, size=hyd_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#             Company_Name Email Company_cities Company_status      company_type
# 3      Navi Technologies                                               Startup
# 16              Justdial                                               Fintech
# 46             Capgemini                                      Featured Company
# 51               PhonePe                                               Startup
# 56              Onetrust                                               Fintech
# ...                  ...   ...            ...            ...               ...
# 14922           Qualiyze                                      Featured Company
# 14938   Nucleus Software                                                   MNC
# 14947             Rupeek                                               Startup
# 14951            PhonePe                                               Startup
# 14965   Nucleus Software                                      Featured Company
#
# [754 rows x 16 columns]

# %%
india_df['Company_Name'] = np.nan
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#        Company_Name Email Company_cities Company_status      company_type
# 3               NaN                                               Startup
# 16              NaN                                               Fintech
# 46              NaN                                      Featured Company
# 51              NaN                                               Startup
# 56              NaN                                               Fintech
# ...             ...   ...            ...            ...               ...
# 14922           NaN                                      Featured Company
# 14938           NaN                                                   MNC
# 14947           NaN                                               Startup
# 14951           NaN                                               Startup
# 14965           NaN                                      Featured Company
#
# [754 rows x 16 columns]

# %%
hyd_mask = india_df['City'] == 'Hyderabad'

hyd_companies = ['Navi Technologies', 'Tide', 'Rupeek', 'PhonePe',
                 'Western Union', 'Capgemini', 'BMC Software',
                 'Qualyze', 'Onetrust', 'Nucleus Software',
                 'Tata Nexarc', 'Justdial', 'Optum']

india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(
    hyd_companies, size=hyd_mask.sum()
)
# Out:
# /tmp/ipykernel_2222/16580222.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['BMC Software' 'BMC Software' 'Capgemini' 'Nucleus Software' 'Capgemini'
#  'Rupeek' 'Navi Technologies' 'Capgemini' 'Western Union' 'Justdial'
#  'Justdial' 'Optum' 'Tata Nexarc' 'Rupeek' 'Optum' 'Western Union'
#  'Nucleus Software' 'Tide' 'Optum' 'PhonePe' 'Onetrust' 'Rupeek'
#  'BMC Software' 'PhonePe' 'Justdial' 'Justdial' 'PhonePe' 'Qualyze'
#  'Nucleus Software' 'Qualyze' 'Onetrust' 'Rupeek' 'Tide' 'Onetrust'
#  'Western Union' 'Justdial' 'Qualyze' 'Tide' 'Capgemini' 'Western Union'
#  'Qualyze' 'Qualyze' 'Tide' 'PhonePe' 'Justdial' 'Tata Nexarc'
#  'Tata Nexarc' 'Tata Nexarc' 'Tide' 'Rupeek' 'Rupeek' 'Nucleus Software'
#  'Rupeek' 'Tata Nexarc' 'PhonePe' 'Tata Nexarc' 'Rupeek' 'Western Union'
#  'Tata Nexarc' 'Tata Nexarc' 'Western Union' 'BMC Software' 'Onetrust'
#  'Capgemini' 'Western Union' 'Optum' 'BMC Software' 'Rupeek' 'Capgemini'
#  'Optum' 'Justdial' 'Western Union' 'PhonePe' 'Optum' 'Optum' 'Rupeek'
#  'BMC Software' 'Western Union' 'BMC Software' 'Optum' 'Western Union'
#  'Onetrust' 'Nucleus Software' 'Rupeek' 'Capgemini' 'Justdial' 'Optum'
#  'Optum' 'Nucleus Software' 'Capgemini' 'Western Union' 'Tide'
#  'Navi Technologies' 'Justdial' 'Navi Technologies' 'Rupeek' 'Optum'
#  'Tata Nexarc' 'BMC Software' 'Western Union' 'Optum' 'Onetrust'
#  'Justdial' 'Navi Technologies' 'PhonePe' 'Qualyze']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(

# %%
india_df.head(100)
# Out:
#        job_id                    job_title  salary_usd salary_currency  \
# 3     AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16    AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46    AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51    AI00052           Research Scientist      115376  US-Doller(USD)
# 56    AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...       ...                          ...         ...             ...
# 2060  AI02061                AI Consultant       57535  US-Doller(USD)
# 2078  AI02079              ML Ops Engineer       43469  US-Doller(USD)
# 2091  AI02092                 AI Architect       85133  US-Doller(USD)
# 2098  AI02099                Data Engineer       63425  US-Doller(USD)
# 2099  AI02100       Deep Learning Engineer       42742  US-Doller(USD)
#
#      experience_level employment_type company_location  \
# 3         Entry level       Freelance            India
# 16        Entry level       Full-Time            India
# 46        Entry level        Contract            India
# 51        Entry level       Full-Time            India
# 56        Entry level       Freelance            India
# ...               ...             ...              ...
# 2060      Entry level       Full-Time            India
# 2078      Entry level        Contract            India
# 2091      Entry level       Part Time            India
# 2098      Entry level        Contract            India
# 2099      Entry level       Full-Time            India
#
#                 company_size employee_residence  remote_ratio       City  \
# 3     multi-national company              India            50  Hyderabad
# 16             Large Company              India           100  Hyderabad
# 46             Small company              India            50     Mumbai
# 51    multi-national company              India           100     Indore
# 56             Large Company              India           100      Noida
# ...                      ...                ...           ...        ...
# 2060           Large Company              India            50     Indore
# 2078           Large Company              India           100       Pune
# 2091           Small company            Denmark           100       Pune
# 2098           Small company     United Kingdom            50     Mumbai
# 2099           Large Company              India            50       Pune
#
#       Company_Name Email Company_cities Company_status      company_type
# 3     BMC Software                                               Startup
# 16    BMC Software                                               Fintech
# 46             NaN                                      Featured Company
# 51             NaN                                               Startup
# 56             NaN                                               Fintech
# ...            ...   ...            ...            ...               ...
# 2060           NaN                                               Startup
# 2078           NaN                                         Product Based
# 2091           NaN                                         Product Based
# 2098           NaN                                         Large Company
# 2099           NaN                                               Startup
#
# [100 rows x 16 columns]

# %%
india_df[
    (india_df['City'] == 'Hyderabad') &
    (india_df['Company_Name'] == 'Tide')
].head(30)
# Out:
#         job_id               job_title  salary_usd salary_currency  \
# 3210   AI03211      AI Product Manager       77445  US-Doller(USD)
# 5767   AI05768           AI Specialist       63505  US-Doller(USD)
# 6290   AI06291            Data Analyst       34670  US-Doller(USD)
# 7056   AI07057  Deep Learning Engineer      101326  US-Doller(USD)
# 7524   AI07525            AI Architect       50056  US-Doller(USD)
# 12708  AI12709       Robotics Engineer       97096  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3210       Entry level       Part Time            India
# 5767       Entry level       Part Time            India
# 6290       Entry level        Contract            India
# 7056       Entry level        Contract            India
# 7524       Entry level       Freelance            India
# 12708      Entry level        Contract            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3210   multi-national company              India            50  Hyderabad
# 5767   multi-national company              India             0  Hyderabad
# 6290            Small company              India             0  Hyderabad
# 7056   multi-national company              India            50  Hyderabad
# 7524            Small company              India            50  Hyderabad
# 12708           Small company              India             0  Hyderabad
#
#       Company_Name Email Company_cities Company_status company_type
# 3210          Tide                                          Startup
# 5767          Tide                                          Fintech
# 6290          Tide                                          Startup
# 7056          Tide                                          Startup
# 7524          Tide                                          Fintech
# 12708         Tide                                          Startup

# %%
india_df[india_df['City'] == 'Hyderabad'].shape[0]
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#        Company_Name Email Company_cities Company_status      company_type
# 3      BMC Software                                               Startup
# 16     BMC Software                                               Fintech
# 46              NaN                                      Featured Company
# 51              NaN                                               Startup
# 56              NaN                                               Fintech
# ...             ...   ...            ...            ...               ...
# 14922           NaN                                      Featured Company
# 14938           NaN                                                   MNC
# 14947           NaN                                               Startup
# 14951           NaN                                               Startup
# 14965           NaN                                      Featured Company
#
# [754 rows x 16 columns]

# %%
mumbai_mask = india_df['City'] == 'Mumbai'
mumbai_mask
# Out:
# 3        False
# 16       False
# 46        True
# 51       False
# 56       False
#          ...
# 14922     True
# 14938     True
# 14947    False
# 14951    False
# 14965     True
# Name: City, Length: 754, dtype: bool

# %%
# mumbai Comapnies name
mumbai_companies = ['TCS', 'Infosys', 'HDFC', 'Reliance', 'Wipro', 'Zerodha', 'CRED']

# %%
# companies status
company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

# %%
import numpy as np

mumbai_mask = india_df['City'] == 'Mumbai'

mumbai_companies = ['TCS', 'Infosys', 'HDFC', 'Reliance', 'Wipro', 'Zerodha', 'CRED']

company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

india_df.loc[mumbai_mask, 'Company_Name'] = np.random.choice(
    mumbai_companies, size=mumbai_mask.sum()
)

india_df.loc[mumbai_mask, 'Company_status'] = np.random.choice(
    company_status, size=mumbai_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#        Company_Name Email Company_cities Company_status      company_type
# 3      BMC Software                                               Startup
# 16     BMC Software                                               Fintech
# 46             HDFC                             Fintech  Featured Company
# 51              NaN                                               Startup
# 56              NaN                                               Fintech
# ...             ...   ...            ...            ...               ...
# 14922         Wipro                             Unicorn  Featured Company
# 14938           TCS                         Top Company               MNC
# 14947           NaN                                               Startup
# 14951           NaN                                               Startup
# 14965      Reliance                             Fintech  Featured Company
#
# [754 rows x 16 columns]

# %%
import numpy as np

# Noida filter
noida_mask = india_df['City'] == 'Noida'

# Noida companies
noida_companies = [
    'HCL Technologies', 'Tech Mahindra', 'Paytm',
    'Adobe India', 'Samsung R&D', 'Infosys', 'Wipro'
]

# Company status
company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

# Assign Company Name
india_df.loc[noida_mask, 'Company_Name'] = np.random.choice(
    noida_companies, size=noida_mask.sum()
)

# Assign Company Status
india_df.loc[noida_mask, 'Company_status'] = np.random.choice(
    company_status, size=noida_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#        Company_Name Email Company_cities Company_status      company_type
# 3      BMC Software                                               Startup
# 16     BMC Software                                               Fintech
# 46             HDFC                             Fintech  Featured Company
# 51              NaN                                               Startup
# 56      Samsung R&D                         Top Company           Fintech
# ...             ...   ...            ...            ...               ...
# 14922         Wipro                             Unicorn  Featured Company
# 14938           TCS                         Top Company               MNC
# 14947         Wipro                       Product Based           Startup
# 14951           NaN                                               Startup
# 14965      Reliance                             Fintech  Featured Company
#
# [754 rows x 16 columns]

# %%
# pune Company status , Company name
pune_mask = india_df['City'] == 'Pune'

pune_companies = [
    'Infosys Pune', 'Cognizant', 'Tech Mahindra',
    'Capgemini Pune', 'TCS Pune', 'Zensar'
]

company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

india_df.loc[pune_mask, 'Company_Name'] = np.random.choice(
    pune_companies, size=pune_mask.sum()
)

india_df.loc[pune_mask, 'Company_status'] = np.random.choice(
    company_status, size=pune_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#        Company_Name Email Company_cities Company_status      company_type
# 3      BMC Software                                               Startup
# 16     BMC Software                                               Fintech
# 46             HDFC                             Fintech  Featured Company
# 51              NaN                                               Startup
# 56      Samsung R&D                         Top Company           Fintech
# ...             ...   ...            ...            ...               ...
# 14922         Wipro                             Unicorn  Featured Company
# 14938           TCS                         Top Company               MNC
# 14947         Wipro                       Product Based           Startup
# 14951     Cognizant                             Fintech           Startup
# 14965      Reliance                             Fintech  Featured Company
#
# [754 rows x 16 columns]

# %%
# Hyderabd Company assign status comapny name
hyd_mask = india_df['City'] == 'Hyderabad'

hyd_companies = [
    'Microsoft', 'Google', 'Amazon',
    'Facebook (Meta)', 'Infosys', 'Wipro', 'Tech Mahindra'
]

india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(
    hyd_companies, size=hyd_mask.sum()
)

india_df.loc[hyd_mask, 'Company_status'] = np.random.choice(
    company_status, size=hyd_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities Company_status      company_type
# 3          Infosys                       Product Based           Startup
# 16          Google                         Top Company           Fintech
# 46            HDFC                             Fintech  Featured Company
# 51             NaN                                               Startup
# 56     Samsung R&D                         Top Company           Fintech
# ...            ...   ...            ...            ...               ...
# 14922        Wipro                             Unicorn  Featured Company
# 14938          TCS                         Top Company               MNC
# 14947        Wipro                       Product Based           Startup
# 14951    Cognizant                             Fintech           Startup
# 14965     Reliance                             Fintech  Featured Company
#
# [754 rows x 16 columns]

# %%
indore_mask = india_df['City'] == 'Indore'

indore_companies = [
    'Impetus', 'TCS Indore', 'Infosys Indore',
    'Yash Technologies', 'Webgility', 'Chapter247'
]

india_df.loc[indore_mask, 'Company_Name'] = np.random.choice(
    indore_companies, size=indore_mask.sum()
)

india_df.loc[indore_mask, 'Company_status'] = np.random.choice(
    company_status, size=indore_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_cities Company_status      company_type
# 3          Infosys                       Product Based           Startup
# 16          Google                         Top Company           Fintech
# 46            HDFC                             Fintech  Featured Company
# 51      Chapter247                         Top Company           Startup
# 56     Samsung R&D                         Top Company           Fintech
# ...            ...   ...            ...            ...               ...
# 14922        Wipro                             Unicorn  Featured Company
# 14938          TCS                         Top Company               MNC
# 14947        Wipro                       Product Based           Startup
# 14951    Cognizant                             Fintech           Startup
# 14965     Reliance                             Fintech  Featured Company
#
# [754 rows x 16 columns]

# %%
india_df.drop('Company_cities',axis=1,inplace=True)
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Email Company_status      company_type
# 3          Infosys        Product Based           Startup
# 16          Google          Top Company           Fintech
# 46            HDFC              Fintech  Featured Company
# 51      Chapter247          Top Company           Startup
# 56     Samsung R&D          Top Company           Fintech
# ...            ...   ...            ...               ...
# 14922        Wipro              Unicorn  Featured Company
# 14938          TCS          Top Company               MNC
# 14947        Wipro        Product Based           Startup
# 14951    Cognizant              Fintech           Startup
# 14965     Reliance              Fintech  Featured Company
#
# [754 rows x 15 columns]

# %%
india_df.drop('Email',axis=1,inplace=True)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# 3          Entry level       Freelance            India
# 16         Entry level       Full-Time            India
# 46         Entry level        Contract            India
# 51         Entry level       Full-Time            India
# 56         Entry level       Freelance            India
# ...                ...             ...              ...
# 14922      Entry level       Full-Time            India
# 14938      Entry level       Full-Time            India
# 14947      Entry level       Part Time            India
# 14951      Entry level        Contract            India
# 14965      Entry level       Part Time            India
#
#                  company_size employee_residence  remote_ratio       City  \
# 3      multi-national company              India            50  Hyderabad
# 16              Large Company              India           100  Hyderabad
# 46              Small company              India            50     Mumbai
# 51     multi-national company              India           100     Indore
# 56              Large Company              India           100      Noida
# ...                       ...                ...           ...        ...
# 14922           Small company              India            50     Mumbai
# 14938  multi-national company        South Korea             0     Mumbai
# 14947           Small company              India             0      Noida
# 14951           Small company              India             0       Pune
# 14965           Small company        Netherlands             0     Mumbai
#
#       Company_Name Company_status      company_type
# 3          Infosys  Product Based           Startup
# 16          Google    Top Company           Fintech
# 46            HDFC        Fintech  Featured Company
# 51      Chapter247    Top Company           Startup
# 56     Samsung R&D    Top Company           Fintech
# ...            ...            ...               ...
# 14922        Wipro        Unicorn  Featured Company
# 14938          TCS    Top Company               MNC
# 14947        Wipro  Product Based           Startup
# 14951    Cognizant        Fintech           Startup
# 14965     Reliance        Fintech  Featured Company
#
# [754 rows x 14 columns]
