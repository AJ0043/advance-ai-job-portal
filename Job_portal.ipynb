# %% [markdown]
# <a href="https://colab.research.google.com/github/AJ0043/advance-ai-job-portal/blob/main/Job_portal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import warnings

# %%
job_title = pd.read_csv("/content/ai_job_dataset-selected-columns.csv")
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
job_title.head(100)
# Out:
#      job_id                    job_title  salary_usd salary_currency  \
# 0   AI00001        AI Research Scientist       90376             USD
# 1   AI00002         AI Software Engineer       61895             USD
# 2   AI00003                AI Specialist      152626             USD
# 3   AI00004                 NLP Engineer       80215             USD
# 4   AI00005                AI Consultant       54624             EUR
# ..      ...                          ...         ...             ...
# 95  AI00096                 NLP Engineer       98688             USD
# 96  AI00097                 Data Analyst      109029             EUR
# 97  AI00098                 NLP Engineer       84797             USD
# 98  AI00099  Machine Learning Researcher      290199             USD
# 99  AI00100        AI Research Scientist      195691             USD
#
#    experience_level employment_type company_location company_size  \
# 0                SE              CT            China            M
# ...

# %%
job_title.shape
# Out:
# (15000, 10)

# %%
job_title.columns
# Out:
# Index(['job_id', 'job_title', 'salary_usd', 'salary_currency',
#        'experience_level', 'employment_type', 'company_location',
#        'company_size', 'employee_residence', 'remote_ratio'],
#       dtype='object')

# %%
job_title.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   job_id              15000 non-null  object
#  1   job_title           15000 non-null  object
#  2   salary_usd          15000 non-null  int64
#  3   salary_currency     15000 non-null  object
#  4   experience_level    15000 non-null  object
#  5   employment_type     15000 non-null  object
#  6   company_location    15000 non-null  object
#  7   company_size        15000 non-null  object
#  8   employee_residence  15000 non-null  object
#  9   remote_ratio        15000 non-null  int64
# dtypes: int64(2), object(8)
# memory usage: 1.1+ MB

# %%
job_title.describe()
# Out:
#           salary_usd  remote_ratio
# count   15000.000000  15000.000000
# mean   115348.965133     49.483333
# std     60260.940438     40.812712
# min     32519.000000      0.000000
# 25%     70179.750000      0.000000
# 50%     99705.000000     50.000000
# 75%    146408.500000    100.000000
# max    399095.000000    100.000000

# %%
job_title.isnull().sum()
# Out:
# job_id                0
# job_title             0
# salary_usd            0
# salary_currency       0
# experience_level      0
# employment_type       0
# company_location      0
# company_size          0
# employee_residence    0
# remote_ratio          0
# dtype: int64

# %%
job_title.duplicated().sum()
# Out:
# np.int64(0)

# %%
job_title = job_title.drop_duplicates()
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
job_title['job_title'].value_counts()
# Out:
# job_title
# Machine Learning Researcher    808
# AI Software Engineer           784
# Autonomous Systems Engineer    777
# Machine Learning Engineer      772
# AI Architect                   771
# Head of AI                     765
# NLP Engineer                   762
# Robotics Engineer              759
# Data Analyst                   759
# AI Research Scientist          756
# Data Engineer                  749
# AI Product Manager             743
# Research Scientist             742
# Principal Data Scientist       734
# AI Specialist                  728
# ML Ops Engineer                725
# Computer Vision Engineer       724
# Data Scientist                 720
# Deep Learning Engineer         718
# AI Consultant                  704
# Name: count, dtype: int64

# %%
job_title['experience_level'].value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
job_title['employment_type'].value_counts()
# Out:
# employment_type
# FT    3812
# FL    3758
# CT    3721
# PT    3709
# Name: count, dtype: int64

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
import matplotlib.pyplot as plt

job_title['job_title'].value_counts().head(10).plot(kind='bar')
plt.show()

# %%
job_title.rename(columns = {'USD':"US Doller"},inplace=True)

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
#job_title['salary_currency'] = job_title['salary_currency'].replace({
 #   'USD': 'Dollar',
 ##   'EUR': 'Euro'
#})

# %%
job_title['salary_currency'].value_counts()
# Out:
# salary_currency
# USD    11957
# EUR     2314
# GBP      729
# Name: count, dtype: int64

# %%
job_title['salary_currency'] = job_title['salary_currency'].replace({
    'USD': 'Dollar',
    'EUR': 'EURO DOller',
    'GBP': 'Great Britesh Pound'


})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 0      AI00001        AI Research Scientist       90376               Dollar
# 1      AI00002         AI Software Engineer       61895               Dollar
# 2      AI00003                AI Specialist      152626               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 4      AI00005                AI Consultant       54624          EURO DOller
# ...        ...                          ...         ...                  ...
# 14995  AI14996            Robotics Engineer       38604               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
# 14997  AI14998                 NLP Engineer      189490               Dollar
# 14998  AI14999                   Head of AI       79461          EURO DOller
# 14999  AI15000     Computer Vision Engineer       56481               Dollar
#
# ...

# %%
#job_title['salary_currency'].value_counts()
job_title['experience_level'].value_counts()
# Out:
# experience_level
# MI    3781
# EX    3760
# SE    3741
# EN    3718
# Name: count, dtype: int64

# %%
job_title['experience_level']=job_title['experience_level'].replace=({
    "SE":'Senior level',
    'EN':'Entry level',
    'MI	': 'Mid level',
    'EX': 'Executive level'
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 0      AI00001        AI Research Scientist       90376               Dollar
# 1      AI00002         AI Software Engineer       61895               Dollar
# 2      AI00003                AI Specialist      152626               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 4      AI00005                AI Consultant       54624          EURO DOller
# ...        ...                          ...         ...                  ...
# 14995  AI14996            Robotics Engineer       38604               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
# 14997  AI14998                 NLP Engineer      189490               Dollar
# 14998  AI14999                   Head of AI       79461          EURO DOller
# 14999  AI15000     Computer Vision Engineer       56481               Dollar
#
# ...

# %%
job_title['employment_type'].value_counts()
# Out:
# employment_type
# FT    3812
# FL    3758
# CT    3721
# PT    3709
# Name: count, dtype: int64

# %%
job_title['employment_type'].replace({
    'FT': 'Full-Time',
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part Time'
}, inplace=True)
# Out:
# /tmp/ipykernel_2348/1148951332.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   job_title['employment_type'].replace({

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 0      AI00001        AI Research Scientist       90376               Dollar
# 1      AI00002         AI Software Engineer       61895               Dollar
# 2      AI00003                AI Specialist      152626               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 4      AI00005                AI Consultant       54624          EURO DOller
# ...        ...                          ...         ...                  ...
# 14995  AI14996            Robotics Engineer       38604               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
# 14997  AI14998                 NLP Engineer      189490               Dollar
# 14998  AI14999                   Head of AI       79461          EURO DOller
# 14999  AI15000     Computer Vision Engineer       56481               Dollar
#
# ...

# %%
job_title['experience_level'].replace({
    'FT': 'Full-Time',
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part Time'
}, inplace=True)
# Out:
# /tmp/ipykernel_2348/359449027.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   job_title['experience_level'].replace({
# /tmp/ipykernel_2348/359449027.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   job_title['experience_level'].replace({

# %%
job_title['experience_level'].unique()
# Out:
# array([nan])

# %%
job_title = job_title_backup.copy()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2348/2457037061.py in <cell line: 0>()
# ----> 1 job_title = job_title_backup.copy()
#
# NameError: name 'job_title_backup' is not defined

# %%
job_title = pd.read_csv("/content/ai_job_dataset-selected-columns.csv")

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
job_title['salary_currency']=job_title['salary_currency'].replace({
    'USD':'US-Doller(USD)',
    'EUR':'Euros(EUR)',
    'GBP':'Great Britesh Pound(GBP)',
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)               SE              CT
# 1                US-Doller(USD)               EN              CT
# 2                US-Doller(USD)               MI              FL
# ...

# %%
job_title_backup = job_title.copy()

# %%
job_title_backup
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency experience_level employment_type  \
# 0                US-Doller(USD)               SE              CT
# 1                US-Doller(USD)               EN              CT
# 2                US-Doller(USD)               MI              FL
# ...

# %%
job_title['experience_level']=job_title['experience_level'].replace({
    'US-Doller(USD)': 'Entry level',
    'Euros(EUR)': 'Senior level',
    'Great Britesh Pound(GBP)': 'middle level',
    'EX': 'Excecutive levels'

})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency   experience_level employment_type  \
# 0                US-Doller(USD)                 SE              CT
# 1                US-Doller(USD)                 EN              CT
# 2                US-Doller(USD)                 MI              FL
# ...

# %%
job_title_backup = job_title.copy()

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency   experience_level employment_type  \
# 0                US-Doller(USD)                 SE              CT
# 1                US-Doller(USD)                 EN              CT
# 2                US-Doller(USD)                 MI              FL
# ...

# %%
job_title['employment_type'] = job_title['employment_type'].replace({
    'FT': 'Full-Time',
    'FL': 'Freelance',
    'CT': 'Contract',
    'PT': 'Part Time'
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency   experience_level employment_type  \
# 0                US-Doller(USD)                 SE        Contract
# 1                US-Doller(USD)                 EN        Contract
# 2                US-Doller(USD)                 MI       Freelance
# ...

# %%
job_title['company_size']=job_title['company_size'].replace({
    'M': 'multi-national company',
    'L': 'Large Company',
    'S':  'Small company'
})

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency   experience_level employment_type  \
# 0                US-Doller(USD)                 SE        Contract
# 1                US-Doller(USD)                 EN        Contract
# 2                US-Doller(USD)                 MI       Freelance
# ...

# %%
job_title[job_title['company_location']=='India'].shape[0]
# Out:
# 754

# %%
#india_jobs = job_title[job_title['company_location'] == 'India']
#india_jobs
india_jobs = job_title[job_title['company_location']=='India']
india_jobs
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
cities = ['Noida', 'Hyderabad', 'Bangalore', 'Pune', 'Mumbai', 'Jaipur', 'Indore']

job_title['City'] = np.random.choice(cities, size=len(job_title))

# %%
job_title
# Out:
#         job_id                    job_title  salary_usd  \
# 0      AI00001        AI Research Scientist       90376
# 1      AI00002         AI Software Engineer       61895
# 2      AI00003                AI Specialist      152626
# 3      AI00004                 NLP Engineer       80215
# 4      AI00005                AI Consultant       54624
# ...        ...                          ...         ...
# 14995  AI14996            Robotics Engineer       38604
# 14996  AI14997  Machine Learning Researcher       57811
# 14997  AI14998                 NLP Engineer      189490
# 14998  AI14999                   Head of AI       79461
# 14999  AI15000     Computer Vision Engineer       56481
#
#                 salary_currency   experience_level employment_type  \
# 0                US-Doller(USD)                 SE        Contract
# 1                US-Doller(USD)                 EN        Contract
# 2                US-Doller(USD)                 MI       Freelance
# ...

# %%
job_title['company_location'].value_counts()
# Out:
# company_location
# Germany           814
# Denmark           778
# Canada            769
# France            769
# Austria           765
# Singapore         764
# China             763
# India             754
# Sweden            752
# Israel            751
# Ireland           750
# Switzerland       746
# Japan             733
# Finland           733
# Australia         732
# Netherlands       731
# United Kingdom    729
# United States     724
# South Korea       722
# Norway            721
# Name: count, dtype: int64

# %%
# I choose Some Countries #
countries = ['India', 'Norway', 'Canada', 'United States',
             'United Kingdom', 'Japan', 'Singapore']

job_title2 = job_title[job_title['company_location'].isin(countries)].copy()

# %%
# New Table Genrate #
job_title2
# Out:
#         job_id                    job_title  salary_usd  \
# 1      AI00002         AI Software Engineer       61895
# 3      AI00004                 NLP Engineer       80215
# 6      AI00007     Principal Data Scientist       79670
# 8      AI00009                 Data Analyst      160710
# 13     AI00014  Autonomous Systems Engineer       68760
# ...        ...                          ...         ...
# 14982  AI14983                 Data Analyst       70721
# 14983  AI14984                 AI Architect      288661
# 14984  AI14985               Data Scientist      138888
# 14991  AI14992            Robotics Engineer       97480
# 14996  AI14997  Machine Learning Researcher       57811
#
#                 salary_currency   experience_level employment_type  \
# 1                US-Doller(USD)                 EN        Contract
# 3                US-Doller(USD)                 SE       Freelance
# 6      Great Britesh Pound(GBP)                 MI       Freelance
# ...

# %%
# dlete city column
job_title2.drop('City',axis=1,inplace=True)
job_title2
# Out:
#         job_id                    job_title  salary_usd  \
# 1      AI00002         AI Software Engineer       61895
# 3      AI00004                 NLP Engineer       80215
# 6      AI00007     Principal Data Scientist       79670
# 8      AI00009                 Data Analyst      160710
# 13     AI00014  Autonomous Systems Engineer       68760
# ...        ...                          ...         ...
# 14982  AI14983                 Data Analyst       70721
# 14983  AI14984                 AI Architect      288661
# 14984  AI14985               Data Scientist      138888
# 14991  AI14992            Robotics Engineer       97480
# 14996  AI14997  Machine Learning Researcher       57811
#
#                 salary_currency   experience_level employment_type  \
# 1                US-Doller(USD)                 EN        Contract
# 3                US-Doller(USD)                 SE       Freelance
# 6      Great Britesh Pound(GBP)                 MI       Freelance
# ...

# %%
 india_df = job_title[job_title['company_location'] == 'India'].copy()
india_df.head(100)
# Out:
#        job_id                    job_title  salary_usd salary_currency  \
# 3     AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16    AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46    AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51    AI00052           Research Scientist      115376  US-Doller(USD)
# 56    AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...       ...                          ...         ...             ...
# 2060  AI02061                AI Consultant       57535  US-Doller(USD)
# 2078  AI02079              ML Ops Engineer       43469  US-Doller(USD)
# 2091  AI02092                 AI Architect       85133  US-Doller(USD)
# 2098  AI02099                Data Engineer       63425  US-Doller(USD)
# 2099  AI02100       Deep Learning Engineer       42742  US-Doller(USD)
#
#        experience_level employment_type company_location  \
# ...

# %%
india_df['Company_Name'] = ""
india_df['Email'] = ""
india_df['Company_cities'] = ""

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df['Company_status'] = ""

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
company_types = [
    'Fintech',
    'Small Company',
    'Large Company',
    'Unicorn',
    'MNC',
    'Startup',
    'Product Based',
    'Featured Company'
]

import numpy as np

india_df['company_type'] = np.random.choice(company_types, size=len(india_df))

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
city_based_types = {
    'Hyderabad': ['Fintech', 'MNC', 'Startup'],
    'Mumbai': ['Large Company', 'MNC', 'Featured Company'],
    'Pune': ['Startup', 'Product Based'],
    'Noida': ['Fintech', 'Startup'],
    'Bangalore': ['Unicorn', 'Product Based', 'Startup'],
    'Indore': ['Small Company', 'Startup']
}

def assign_company_type(city):
    return np.random.choice(city_based_types.get(city, company_types))

india_df['company_type'] = india_df['City'].apply(assign_company_type)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
# city in hydrabd
hyd_df = india_df[india_df['City'] == 'Hyderabad'].copy()
hyd_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 545    AI00546    Machine Learning Engineer       35782  US-Doller(USD)
# 689    AI00690                 Data Analyst       89120  US-Doller(USD)
# 844    AI00845                 AI Architect       59833  US-Doller(USD)
# 1112   AI01113  Autonomous Systems Engineer       82330  US-Doller(USD)
# 1276   AI01277           AI Product Manager       88025  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14725  AI14726       Deep Learning Engineer       55000  US-Doller(USD)
# 14738  AI14739                 NLP Engineer       88970  US-Doller(USD)
# 14741  AI14742  Machine Learning Researcher       47320  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
# Make a Comman list in the india_df
fintech_companies = ['Navi Technologies', 'Tide', 'Rupeek', 'PhonePe']
mnc_companies = ['Western Union', 'Capgemini', 'BMC Software']
product_companies = ['Qualiyze', 'Onetrust', 'Nucleus Software']
top_companies = ['Tata Nexarc', 'Justdial', 'Optum']

all_companies = fintech_companies + mnc_companies + product_companies + top_companies

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
# Comapny Name
india_df['Company_Name'] = np.random.choice(all_companies, size=len(india_df))

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
# Hyderabad wali rows filter
hyd_mask = india_df['City'] == 'Hyderabad'

# Hyderabad companies list
hyd_companies = ['Navi Technologies', 'Tide', 'Rupeek', 'PhonePe',
                 'Western Union', 'Capgemini', 'BMC Software',
                 'Qualyze', 'Onetrust', 'Nucleus Software',
                 'Tata Nexarc', 'Justdial', 'Optum']

# Sirf Hyderabad rows me assign karo
india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(
    hyd_companies, size=hyd_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df['Company_Name'] = np.nan
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
hyd_mask = india_df['City'] == 'Hyderabad'

hyd_companies = ['Navi Technologies', 'Tide', 'Rupeek', 'PhonePe',
                 'Western Union', 'Capgemini', 'BMC Software',
                 'Qualyze', 'Onetrust', 'Nucleus Software',
                 'Tata Nexarc', 'Justdial', 'Optum']

india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(
    hyd_companies, size=hyd_mask.sum()
)
# Out:
# /tmp/ipykernel_2348/16580222.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '['PhonePe' 'Qualyze' 'Optum' 'Nucleus Software' 'Nucleus Software'
#  'BMC Software' 'BMC Software' 'Nucleus Software' 'Tata Nexarc' 'Justdial'
#  'Tide' 'PhonePe' 'Nucleus Software' 'PhonePe' 'Justdial' 'Onetrust'
#  'Nucleus Software' 'Tide' 'BMC Software' 'Navi Technologies' 'Tide'
#  'Onetrust' 'Qualyze' 'Navi Technologies' 'Optum' 'Onetrust' 'PhonePe'
#  'Capgemini' 'Justdial' 'Capgemini' 'BMC Software' 'PhonePe'
#  'BMC Software' 'BMC Software' 'Nucleus Software' 'Optum' 'PhonePe'
#  'BMC Software' 'Nucleus Software' 'Nucleus Software' 'BMC Software'
#  'Capgemini' 'BMC Software' 'Tide' 'Capgemini' 'Nucleus Software'
#  'Capgemini' 'Justdial' 'Qualyze' 'Qualyze' 'Justdial' 'BMC Software'
#  'Tide' 'Justdial' 'BMC Software' 'Tata Nexarc' 'Tata Nexarc'
# ...

# %%
india_df.head(100)
# Out:
#        job_id                    job_title  salary_usd salary_currency  \
# 3     AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16    AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46    AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51    AI00052           Research Scientist      115376  US-Doller(USD)
# 56    AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...       ...                          ...         ...             ...
# 2060  AI02061                AI Consultant       57535  US-Doller(USD)
# 2078  AI02079              ML Ops Engineer       43469  US-Doller(USD)
# 2091  AI02092                 AI Architect       85133  US-Doller(USD)
# 2098  AI02099                Data Engineer       63425  US-Doller(USD)
# 2099  AI02100       Deep Learning Engineer       42742  US-Doller(USD)
#
#        experience_level employment_type company_location  \
# ...

# %%
india_df[
    (india_df['City'] == 'Hyderabad') &
    (india_df['Company_Name'] == 'Tide')
].head(30)
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 2091   AI02092                 AI Architect       85133  US-Doller(USD)
# 2814   AI02815  Machine Learning Researcher       59970  US-Doller(USD)
# 3203   AI03204       Deep Learning Engineer      124640  US-Doller(USD)
# 6196   AI06197                 NLP Engineer      183130  US-Doller(USD)
# 7193   AI07194         AI Software Engineer       59191  US-Doller(USD)
# 9005   AI09006                 NLP Engineer      101052  US-Doller(USD)
# 10902  AI10903  Machine Learning Researcher       47747  US-Doller(USD)
# 13894  AI13895                 AI Architect       33918  US-Doller(USD)
# 14738  AI14739                 NLP Engineer       88970  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# 2091                  SE       Part Time            India
# 2814                  MI       Freelance            India
# 3203   Excecutive levels        Contract            India
# ...

# %%
india_df[india_df['City'] == 'Hyderabad'].shape[0]
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
mumbai_mask = india_df['City'] == 'Mumbai'
mumbai_mask
# Out:
# 3        False
# 16       False
# 46       False
# 51       False
# 56       False
#          ...
# 14922    False
# 14938    False
# 14947    False
# 14951    False
# 14965    False
# Name: City, Length: 754, dtype: bool

# %%
# mumbai Comapnies name
mumbai_companies = ['TCS', 'Infosys', 'HDFC', 'Reliance', 'Wipro', 'Zerodha', 'CRED']

# %%
# companies status
company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

# %%
import numpy as np

mumbai_mask = india_df['City'] == 'Mumbai'

mumbai_companies = ['TCS', 'Infosys', 'HDFC', 'Reliance', 'Wipro', 'Zerodha', 'CRED']

company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

india_df.loc[mumbai_mask, 'Company_Name'] = np.random.choice(
    mumbai_companies, size=mumbai_mask.sum()
)

india_df.loc[mumbai_mask, 'Company_status'] = np.random.choice(
    company_status, size=mumbai_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
import numpy as np

# Noida filter
noida_mask = india_df['City'] == 'Noida'

# Noida companies
noida_companies = [
    'HCL Technologies', 'Tech Mahindra', 'Paytm',
    'Adobe India', 'Samsung R&D', 'Infosys', 'Wipro'
]

# Company status
company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

# Assign Company Name
india_df.loc[noida_mask, 'Company_Name'] = np.random.choice(
    noida_companies, size=noida_mask.sum()
)

# Assign Company Status
india_df.loc[noida_mask, 'Company_status'] = np.random.choice(
    company_status, size=noida_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
# pune Company status , Company name
pune_mask = india_df['City'] == 'Pune'

pune_companies = [
    'Infosys Pune', 'Cognizant', 'Tech Mahindra',
    'Capgemini Pune', 'TCS Pune', 'Zensar'
]

company_status = ['Fintech', 'Unicorn', 'Startup', 'Product Based', 'Top Company']

india_df.loc[pune_mask, 'Company_Name'] = np.random.choice(
    pune_companies, size=pune_mask.sum()
)

india_df.loc[pune_mask, 'Company_status'] = np.random.choice(
    company_status, size=pune_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
# Hyderabd Company assign status comapny name
hyd_mask = india_df['City'] == 'Hyderabad'

hyd_companies = [
    'Microsoft', 'Google', 'Amazon',
    'Facebook (Meta)', 'Infosys', 'Wipro', 'Tech Mahindra'
]

india_df.loc[hyd_mask, 'Company_Name'] = np.random.choice(
    hyd_companies, size=hyd_mask.sum()
)

india_df.loc[hyd_mask, 'Company_status'] = np.random.choice(
    company_status, size=hyd_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
indore_mask = india_df['City'] == 'Indore'

indore_companies = [
    'Impetus', 'TCS Indore', 'Infosys Indore',
    'Yash Technologies', 'Webgility', 'Chapter247'
]

india_df.loc[indore_mask, 'Company_Name'] = np.random.choice(
    indore_companies, size=indore_mask.sum()
)

india_df.loc[indore_mask, 'Company_status'] = np.random.choice(
    company_status, size=indore_mask.sum()
)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df.drop('Company_cities',axis=1,inplace=True)
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df.drop('Email',axis=1,inplace=True)

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df.columns
# Out:
# Index(['job_id', 'job_title', 'salary_usd', 'salary_currency',
#        'experience_level', 'employment_type', 'company_location',
#        'company_size', 'employee_residence', 'remote_ratio', 'City',
#        'Company_Name', 'Company_status', 'company_type'],
#       dtype='object')

# %%
india_df['Company_status'].value_counts()
# Out:
# Company_status
#                  316
# Top Company       96
# Startup           94
# Unicorn           84
# Product Based     83
# Fintech           81
# Name: count, dtype: int64

# %%
india_df['City'].value_counts()
# Out:
# City
# Mumbai       118
# Hyderabad    115
# Noida        112
# Pune         109
# Bangalore    105
# Jaipur        99
# Indore        96
# Name: count, dtype: int64

# %%
india_df['Salary_Rupees'] = india_df['salary_usd'] * 83

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df[['salary_usd', 'Salary_Rupees']].head()
# Out:
#     salary_usd  Salary_Rupees
# 3        80215        6657845
# 16       59823        4965309
# 46       46753        3880499
# 51      115376        9576208
# 56       79863        6628629

# %%
india_df['salary_usd_thousands'] = india_df['salary_usd'] / 1000

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#         experience_level employment_type company_location  \
# ...

# %%
india_df['experience_level'].unique()
# Out:
# array(['SE', 'EN', 'Excecutive levels', 'MI'], dtype=object)

# %%
india_df['experience_level'] = india_df['experience_level'].map({
    'EN': 'Entry Level',
    'MI': 'Mid Level',
    'SE': 'Senior Level',
    'Excecutive levels': 'Executive Level'
})

# %%
india_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 3      AI00004                 NLP Engineer       80215  US-Doller(USD)
# 16     AI00017     Principal Data Scientist       59823  US-Doller(USD)
# 46     AI00047        AI Research Scientist       46753  US-Doller(USD)
# 51     AI00052           Research Scientist      115376  US-Doller(USD)
# 56     AI00057  Autonomous Systems Engineer       79863  US-Doller(USD)
# ...        ...                          ...         ...             ...
# 14922  AI14923         AI Software Engineer       59649  US-Doller(USD)
# 14938  AI14939                   Head of AI       56095  US-Doller(USD)
# 14947  AI14948               Data Scientist       96629  US-Doller(USD)
# 14951  AI14952        AI Research Scientist       36376  US-Doller(USD)
# 14965  AI14966               Data Scientist       88191  US-Doller(USD)
#
#       experience_level employment_type company_location  \
# ...

# %%
india_df.drop('salary_usd', axis=1, inplace=True, errors='ignore')

# %%
india_df
# Out:
#         job_id                    job_title salary_currency experience_level  \
# 3      AI00004                 NLP Engineer  US-Doller(USD)     Senior Level
# 16     AI00017     Principal Data Scientist  US-Doller(USD)      Entry Level
# 46     AI00047        AI Research Scientist  US-Doller(USD)      Entry Level
# 51     AI00052           Research Scientist  US-Doller(USD)  Executive Level
# 56     AI00057  Autonomous Systems Engineer  US-Doller(USD)        Mid Level
# ...        ...                          ...             ...              ...
# 14922  AI14923         AI Software Engineer  US-Doller(USD)        Mid Level
# 14938  AI14939                   Head of AI  US-Doller(USD)      Entry Level
# 14947  AI14948               Data Scientist  US-Doller(USD)  Executive Level
# 14951  AI14952        AI Research Scientist  US-Doller(USD)      Entry Level
# 14965  AI14966               Data Scientist  US-Doller(USD)     Senior Level
#
# ...

# %%
india_df.drop('salary_usd_thousands', axis=1, inplace=True, errors='ignore')

# %%
india_df
# Out:
#         job_id                    job_title salary_currency experience_level  \
# 3      AI00004                 NLP Engineer  US-Doller(USD)     Senior Level
# 16     AI00017     Principal Data Scientist  US-Doller(USD)      Entry Level
# 46     AI00047        AI Research Scientist  US-Doller(USD)      Entry Level
# 51     AI00052           Research Scientist  US-Doller(USD)  Executive Level
# 56     AI00057  Autonomous Systems Engineer  US-Doller(USD)        Mid Level
# ...        ...                          ...             ...              ...
# 14922  AI14923         AI Software Engineer  US-Doller(USD)        Mid Level
# 14938  AI14939                   Head of AI  US-Doller(USD)      Entry Level
# 14947  AI14948               Data Scientist  US-Doller(USD)  Executive Level
# 14951  AI14952        AI Research Scientist  US-Doller(USD)      Entry Level
# 14965  AI14966               Data Scientist  US-Doller(USD)     Senior Level
#
# ...

# %%
india_df.drop('salary_currency', axis=1, inplace=True, errors='ignore')

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df.drop('experience_level_full', axis=1, inplace=True, errors='ignore')

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['experience_years'] = india_df['experience_level'].map({
    'Entry Level': 1,   # Entry Level → 1 year
    'Mid Level': 3,   # Mid Level → 3 years
    'Senior Level': 6,   # Senior Level → 6 years
    'Executive Level': 10  # Executive → 10 years
})

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
min_exp = india_df['experience_years'].min()
max_exp = india_df['experience_years'].max()

india_df['Salary_Rupees'] = (
    (india_df['experience_years'] - min_exp) / (max_exp - min_exp)
) * (50 - 10) + 10

# LPA → Rupees
india_df['Salary_Rupees'] = india_df['Salary_Rupees'] * 100000

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['Salary_Rupees'] = india_df['Salary_Rupees'].round(0).astype(int)

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['Salary_LPA'] = (india_df['Salary_Rupees'] / 100000).round(2)

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
def calculate_tax(row):
    salary = row['Salary_LPA']
    location = row['company_location']

    # base tax
    if salary <= 12:
        tax = 0.10
    elif salary <= 30:
        tax = 0.20
    else:
        tax = 0.30

    # metro extra tax
    if location in ['Mumbai', 'Delhi', 'Bangalore']:
        tax += 0.02

    return tax

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['Tax_Percentage'] = india_df.apply(calculate_tax, axis=1)

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['Tax_%'] = (india_df['Tax_Percentage'] * 100).astype(int).astype(str) + '%'

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['Salary_In_Hand'] = india_df['Salary_Rupees'] * (1 - india_df['Tax_Percentage'])

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df['skills'] = india_df['job_title'].map(skills_map)

# %%
skills_map = {
    'Data Scientist': 'Python, ML, Statistics, Pandas',
    'AI Research Scientist': 'Deep Learning, NLP, PyTorch',
    'AI Software Engineer': 'Python, APIs, ML Deployment',
    'NLP Engineer': 'NLP, Text Processing, Transformers',
    'Research Scientist': 'Research, Python, Data Analysis',
    'Head of AI': 'Leadership, AI Strategy, ML',
    'Autonomous Systems Engineer': 'Robotics, Computer Vision, AI'
}

# %%
india_df['skills'] = india_df['job_title'].map(skills_map)

# %%
def assign_skills(title):
    title = str(title).lower()

    if 'data scientist' in title:
        return 'Python, ML, Statistics, Pandas'
    elif 'ai research' in title:
        return 'Deep Learning, NLP, PyTorch'
    elif 'nlp' in title:
        return 'NLP, Transformers, Text Processing'
    elif 'software engineer' in title:
        return 'Python, APIs, Deployment'
    elif 'research' in title:
        return 'Research, Python, Analysis'
    elif 'head' in title:
        return 'Leadership, Strategy, AI'
    else:
        return 'General Tech Skills'

india_df['skills'] = india_df['job_title'].apply(assign_skills)

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
def add_description(skill):
    skill = str(skill).lower()

    if 'python' in skill:
        return """• Strong knowledge of Python programming (Mandatory)
• Bachelor's degree in Computer Science or related field
• 2–5 years of hands-on experience in development or data roles
• Experience in data analysis and machine learning
• Problem-solving and analytical thinking skills
• Ability to work with real-world datasets
• Good communication and teamwork abilities"""

    elif 'nlp' in skill:
        return """• Strong knowledge of Python (Mandatory)
• Bachelor's/Master’s degree in AI, Data Science or related field
• 3–6 years of experience in NLP projects
• Experience with text processing and language models
• Hands-on work with transformers and deep learning
• Strong analytical and problem-solving skills"""

    elif 'deep learning' in skill:
        return """• Strong Python programming skills (Mandatory)
• Degree in Computer Science, AI or related domain
• 4–8 years of experience in deep learning
• Experience with TensorFlow or PyTorch
• Knowledge of neural networks and model optimization
• Ability to handle large-scale data and models"""

    else:
        return """• Strong knowledge of Python (Mandatory)
• Bachelor’s degree in relevant technical field
• 2–4 years of professional experience
• Good understanding of technical concepts
• Problem-solving and teamwork skills
• Willingness to learn and adapt new technologies"""

# %%
india_df['description'] = india_df['skills'].apply(add_description)

# %%
india_df
# Out:
#         job_id                    job_title experience_level employment_type  \
# 3      AI00004                 NLP Engineer     Senior Level       Freelance
# 16     AI00017     Principal Data Scientist      Entry Level       Full-Time
# 46     AI00047        AI Research Scientist      Entry Level        Contract
# 51     AI00052           Research Scientist  Executive Level       Full-Time
# 56     AI00057  Autonomous Systems Engineer        Mid Level       Freelance
# ...        ...                          ...              ...             ...
# 14922  AI14923         AI Software Engineer        Mid Level       Full-Time
# 14938  AI14939                   Head of AI      Entry Level       Full-Time
# 14947  AI14948               Data Scientist  Executive Level       Part Time
# 14951  AI14952        AI Research Scientist      Entry Level        Contract
# 14965  AI14966               Data Scientist     Senior Level       Part Time
#
# ...

# %%
india_df.describe()
# Out:
#        remote_ratio  Salary_Rupees  experience_years  Salary_LPA  \
# count    754.000000   7.540000e+02        754.000000  754.000000
# mean      51.127321   2.714117e+06          4.856764   27.140889
# std       40.931092   1.471163e+06          3.310118   14.711270
# min        0.000000   1.000000e+06          1.000000   10.000000
# 25%        0.000000   1.222222e+06          1.500000   12.222500
# 50%       50.000000   1.888889e+06          3.000000   18.890000
# 75%      100.000000   3.222222e+06          6.000000   32.220000
# max      100.000000   5.000000e+06         10.000000   50.000000
#
#        Tax_Percentage  Salary_In_Hand
# count      754.000000    7.540000e+02
# mean         0.223475    1.999867e+06
# std          0.082576    9.443717e+05
# min          0.100000    9.000000e+05
# 25%          0.125000    1.052778e+06
# 50%          0.200000    1.511111e+06
# 75%          0.300000    2.255555e+06
# max          0.300000    3.500000e+06

# %%
india_df.columns
# Out:
# Index(['job_id', 'job_title', 'experience_level', 'employment_type',
#        'company_location', 'company_size', 'employee_residence',
#        'remote_ratio', 'City', 'Company_Name', 'Company_status',
#        'company_type', 'Salary_Rupees', 'experience_years', 'Salary_LPA',
#        'Tax_Percentage', 'Tax_%', 'Salary_In_Hand', 'skills', 'description'],
#       dtype='object')

# %%
india_df.shape
# Out:
# (754, 20)

# %%
job_title2 = pd.read_csv("/content/ai_job_dataset-selected-columns.csv")
job_title2
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 0      AI00001        AI Research Scientist       90376             USD
# 1      AI00002         AI Software Engineer       61895             USD
# 2      AI00003                AI Specialist      152626             USD
# 3      AI00004                 NLP Engineer       80215             USD
# 4      AI00005                AI Consultant       54624             EUR
# ...        ...                          ...         ...             ...
# 14995  AI14996            Robotics Engineer       38604             USD
# 14996  AI14997  Machine Learning Researcher       57811             GBP
# 14997  AI14998                 NLP Engineer      189490             USD
# 14998  AI14999                   Head of AI       79461             EUR
# 14999  AI15000     Computer Vision Engineer       56481             USD
#
#       experience_level employment_type company_location company_size  \
# ...

# %%
# I choose Some Countries #
# I choose Some Countries #
countries = ['India', 'Norway', 'Canada', 'United States',
             'United Kingdom', 'Japan', 'Singapore']

job_title3 = job_title[job_title['company_location'].isin(countries)].copy()

# %%
job_title3
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 1      AI00002         AI Software Engineer       61895               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 6      AI00007     Principal Data Scientist       79670  Great Britesh Pound
# 8      AI00009                 Data Analyst      160710               Dollar
# 13     AI00014  Autonomous Systems Engineer       68760               Dollar
# ...        ...                          ...         ...                  ...
# 14982  AI14983                 Data Analyst       70721               Dollar
# 14983  AI14984                 AI Architect      288661               Dollar
# 14984  AI14985               Data Scientist      138888               Dollar
# 14991  AI14992            Robotics Engineer       97480               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
#
# ...

# %%
# Norway data Set #
job_title3
# Out:
#         job_id                    job_title  salary_usd      salary_currency  \
# 1      AI00002         AI Software Engineer       61895               Dollar
# 3      AI00004                 NLP Engineer       80215               Dollar
# 6      AI00007     Principal Data Scientist       79670  Great Britesh Pound
# 8      AI00009                 Data Analyst      160710               Dollar
# 13     AI00014  Autonomous Systems Engineer       68760               Dollar
# ...        ...                          ...         ...                  ...
# 14982  AI14983                 Data Analyst       70721               Dollar
# 14983  AI14984                 AI Architect      288661               Dollar
# 14984  AI14985               Data Scientist      138888               Dollar
# 14991  AI14992            Robotics Engineer       97480               Dollar
# 14996  AI14997  Machine Learning Researcher       57811  Great Britesh Pound
#
# ...

# %%
norway_df = job_title3[job_title3['company_location'] == 'Norway']

# %%
norway_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 13     AI00014  Autonomous Systems Engineer       68760          Dollar
# 20     AI00021                Data Engineer      134197          Dollar
# 53     AI00054               Data Scientist      135230          Dollar
# 61     AI00062               Data Scientist      162296          Dollar
# 72     AI00073  Machine Learning Researcher      124820          Dollar
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager      112928          Dollar
# 14917  AI14918              ML Ops Engineer      273053          Dollar
# 14976  AI14977                AI Consultant      164620          Dollar
# 14977  AI14978           Research Scientist      325968          Dollar
# 14982  AI14983                 Data Analyst       70721          Dollar
#
#        experience_level employment_type company_location company_size  \
# ...

# %%
norway_df['company_location'].unique()
# Out:
# array(['Norway'], dtype=object)

# %%
norway_df = job_title3[job_title3['company_location'] == 'NO']

# %%
#india_df['company_location'] = india_df['company_location'].str.strip()

norway_df = job_title3[job_title3['company_location'].isin(['NO', 'Norway'])]

# %%
norway_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 13     AI00014  Autonomous Systems Engineer       68760          Dollar
# 20     AI00021                Data Engineer      134197          Dollar
# 53     AI00054               Data Scientist      135230          Dollar
# 61     AI00062               Data Scientist      162296          Dollar
# 72     AI00073  Machine Learning Researcher      124820          Dollar
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager      112928          Dollar
# 14917  AI14918              ML Ops Engineer      273053          Dollar
# 14976  AI14977                AI Consultant      164620          Dollar
# 14977  AI14978           Research Scientist      325968          Dollar
# 14982  AI14983                 Data Analyst       70721          Dollar
#
#        experience_level employment_type company_location company_size  \
# ...

# %%
norway_df.shape
# Out:
# (721, 10)

# %%
norway_df
# Out:
#         job_id                    job_title  salary_usd salary_currency  \
# 13     AI00014  Autonomous Systems Engineer       68760          Dollar
# 20     AI00021                Data Engineer      134197          Dollar
# 53     AI00054               Data Scientist      135230          Dollar
# 61     AI00062               Data Scientist      162296          Dollar
# 72     AI00073  Machine Learning Researcher      124820          Dollar
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager      112928          Dollar
# 14917  AI14918              ML Ops Engineer      273053          Dollar
# 14976  AI14977                AI Consultant      164620          Dollar
# 14977  AI14978           Research Scientist      325968          Dollar
# 14982  AI14983                 Data Analyst       70721          Dollar
#
#        experience_level employment_type company_location company_size  \
# ...

# %%
conversion_rate = 10.5

# %%
norway_df['Salary_NOK'] = norway_df['salary_usd'] * conversion_rate
# Out:
# /tmp/ipykernel_2348/1169821216.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norway_df['Salary_NOK'] = norway_df['salary_usd'] * conversion_rate

# %%
norway_df['Salary_NOK'] = norway_df['Salary_NOK'].astype(int)
norway_df
# Out:
# /tmp/ipykernel_2348/1889833207.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   norway_df['Salary_NOK'] = norway_df['Salary_NOK'].astype(int)
#         job_id                    job_title  salary_usd salary_currency  \
# 13     AI00014  Autonomous Systems Engineer       68760          Dollar
# 20     AI00021                Data Engineer      134197          Dollar
# 53     AI00054               Data Scientist      135230          Dollar
# 61     AI00062               Data Scientist      162296          Dollar
# 72     AI00073  Machine Learning Researcher      124820          Dollar
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager      112928          Dollar
# ...

# %%
cols = list(norway_df.columns)

# Salary_NOK ko remove kar do list se
cols.remove('Salary_NOK')

# job_title ka index nikaal
idx = cols.index('job_title')

# Salary_NOK ko job_title ke baad insert karo
cols.insert(idx + 1, 'Salary_NOK')

# DataFrame reorder
norway_df = norway_df[cols]

norway_df
# Out:
#         job_id                    job_title  Salary_NOK  salary_usd  \
# 13     AI00014  Autonomous Systems Engineer      721980       68760
# 20     AI00021                Data Engineer     1409068      134197
# 53     AI00054               Data Scientist     1419915      135230
# 61     AI00062               Data Scientist     1704108      162296
# 72     AI00073  Machine Learning Researcher     1310610      124820
# ...        ...                          ...         ...         ...
# 14904  AI14905           AI Product Manager     1185744      112928
# 14917  AI14918              ML Ops Engineer     2867056      273053
# 14976  AI14977                AI Consultant     1728510      164620
# 14977  AI14978           Research Scientist     3422664      325968
# 14982  AI14983                 Data Analyst      742570       70721
#
#       salary_currency  experience_level employment_type company_location  \
# 13             Dollar               NaN        Contract           Norway
# ...

# %%
norway_df = norway_df.drop('salary_usd', axis=1)

norway_df
# Out:
#         job_id                    job_title  Salary_NOK salary_currency  \
# 13     AI00014  Autonomous Systems Engineer      721980          Dollar
# 20     AI00021                Data Engineer     1409068          Dollar
# 53     AI00054               Data Scientist     1419915          Dollar
# 61     AI00062               Data Scientist     1704108          Dollar
# 72     AI00073  Machine Learning Researcher     1310610          Dollar
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager     1185744          Dollar
# 14917  AI14918              ML Ops Engineer     2867056          Dollar
# 14976  AI14977                AI Consultant     1728510          Dollar
# 14977  AI14978           Research Scientist     3422664          Dollar
# 14982  AI14983                 Data Analyst      742570          Dollar
#
#        experience_level employment_type company_location company_size  \
# ...

# %%
norway_df['salary_currency'] = norway_df['salary_currency'].map({
    'US-Doller(USD)': 'NOK'
})

# %%
norway_df
# Out:
#         job_id                    job_title  Salary_NOK salary_currency  \
# 13     AI00014  Autonomous Systems Engineer      721980             NaN
# 20     AI00021                Data Engineer     1409068             NaN
# 53     AI00054               Data Scientist     1419915             NaN
# 61     AI00062               Data Scientist     1704108             NaN
# 72     AI00073  Machine Learning Researcher     1310610             NaN
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager     1185744             NaN
# 14917  AI14918              ML Ops Engineer     2867056             NaN
# 14976  AI14977                AI Consultant     1728510             NaN
# 14977  AI14978           Research Scientist     3422664             NaN
# 14982  AI14983                 Data Analyst      742570             NaN
#
#        experience_level employment_type company_location company_size  \
# ...

# %%
norway_df = norway_df.drop('salary_currency_NOK', axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2348/3149588841.py in <cell line: 0>()
# ----> 1 norway_df = norway_df.drop('salary_currency_NOK', axis=1)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
norway_df
# Out:
#         job_id                    job_title  Salary_NOK salary_currency  \
# 13     AI00014  Autonomous Systems Engineer      721980             NaN
# 20     AI00021                Data Engineer     1409068             NaN
# 53     AI00054               Data Scientist     1419915             NaN
# 61     AI00062               Data Scientist     1704108             NaN
# 72     AI00073  Machine Learning Researcher     1310610             NaN
# ...        ...                          ...         ...             ...
# 14904  AI14905           AI Product Manager     1185744             NaN
# 14917  AI14918              ML Ops Engineer     2867056             NaN
# 14976  AI14977                AI Consultant     1728510             NaN
# 14977  AI14978           Research Scientist     3422664             NaN
# 14982  AI14983                 Data Analyst      742570             NaN
#
#        experience_level employment_type company_location company_size  \
# ...

# %%
norway_df['experience_level'] = norway_df['experience_level'].map({
    'EN': "Entry_Level",
    'SE': "Senior_Level",
    'MI': "Mid_level",
    'Excecutive_level':"Excecutive_level"
})

# %%
norway_df

# %%
# 4 new columns add
norway_df[['Company_Type', 'Industry', 'Is_AI_Company', 'Company_Name']] = None

# check output
norway_df.head()
# Out:
#      job_id                    job_title  Salary_NOK salary_currency  \
# 13  AI00014  Autonomous Systems Engineer      721980             NaN
# 20  AI00021                Data Engineer     1409068             NaN
# 53  AI00054               Data Scientist     1419915             NaN
# 61  AI00062               Data Scientist     1704108             NaN
# 72  AI00073  Machine Learning Researcher     1310610             NaN
#
#    experience_level employment_type company_location company_size  \
# 13              NaN        Contract           Norway            S
# 20              NaN       Full-Time           Norway            M
# 53              NaN       Part Time           Norway            S
# 61              NaN       Part Time           Norway            S
# 72              NaN       Freelance           Norway            S
#
#    employee_residence  remote_ratio Company_Type Industry Is_AI_Company  \
# 13             Norway             0         None     None          None
# ...

# %%
norway_df.to_csv("norway_cleaned.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2341/372846590.py in <cell line: 0>()
# ----> 1 norway_df.to_csv("norway_cleaned.csv", index=False)
#
# NameError: name 'norway_df' is not defined

# %%
import pandas as pd
norway_df = pd.read_csv("norway_cleaned.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
norway_df = norway_df.to_csv('/content/drive/MyDrive/norway_cleaned.csv', index=False)

# %%
norway_df

# %%
norway_df1 = pd.read_csv("/content/norway_cleaned.csv")

# %%
norway_df1
# Out:
#       job_id                    job_title  Salary_NOK  salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980              NaN
# 1    AI00021                Data Engineer     1409068              NaN
# 2    AI00054               Data Scientist     1419915              NaN
# 3    AI00062               Data Scientist     1704108              NaN
# 4    AI00073  Machine Learning Researcher     1310610              NaN
# ..       ...                          ...         ...              ...
# 716  AI14905           AI Product Manager     1185744              NaN
# 717  AI14918              ML Ops Engineer     2867056              NaN
# 718  AI14977                AI Consultant     1728510              NaN
# 719  AI14978           Research Scientist     3422664              NaN
# 720  AI14983                 Data Analyst      742570              NaN
#
#      experience_level employment_type company_location company_size  \
# ...

# %%
norway_df1['salary_currency'] = 'NOK'

# %%
norway_df1
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 1    AI00021                Data Engineer     1409068             NOK
# 2    AI00054               Data Scientist     1419915             NOK
# 3    AI00062               Data Scientist     1704108             NOK
# 4    AI00073  Machine Learning Researcher     1310610             NOK
# ..       ...                          ...         ...             ...
# 716  AI14905           AI Product Manager     1185744             NOK
# 717  AI14918              ML Ops Engineer     2867056             NOK
# 718  AI14977                AI Consultant     1728510             NOK
# 719  AI14978           Research Scientist     3422664             NOK
# 720  AI14983                 Data Analyst      742570             NOK
#
#      experience_level employment_type company_location company_size  \
# ...

# %%
mapping = {
    'EN': 'Entry Level',
    'MI': 'Mid Level',
    'SE': 'Senior Level',
    'EX': 'Executive Level'
}

# %%
norway_df1['experience_level'] = norway_df1['experience_level'].map(mapping)

# %%
norway_df1['experience_level'] = norway_df1['experience_level'].replace({
    'Entry_Level': 'Entry Level',
    'Mid_Level': 'Mid Level',
    'Senior_Level': 'Senior Level',
    'Executive_Level': 'Executive Level'
})
# Out:
# /tmp/ipykernel_2341/3455763785.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   norway_df1['experience_level'] = norway_df1['experience_level'].replace({

# %%
norway_df1['experience_level'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
norway_df1
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 1    AI00021                Data Engineer     1409068             NOK
# 2    AI00054               Data Scientist     1419915             NOK
# 3    AI00062               Data Scientist     1704108             NOK
# 4    AI00073  Machine Learning Researcher     1310610             NOK
# ..       ...                          ...         ...             ...
# 716  AI14905           AI Product Manager     1185744             NOK
# 717  AI14918              ML Ops Engineer     2867056             NOK
# 718  AI14977                AI Consultant     1728510             NOK
# 719  AI14978           Research Scientist     3422664             NOK
# 720  AI14983                 Data Analyst      742570             NOK
#
#      experience_level employment_type company_location company_size  \
# ...

# %%
norway_df1['experience_level'] = norway_df1['experience_level'].fillna('Not Specified')

# %%
def fill_exp(job):
    job = str(job).lower()

    if 'senior' in job or 'lead' in job:
        return 'Senior Level'
    elif 'manager' in job or 'head' in job:
        return 'Executive Level'
    elif 'engineer' in job or 'analyst' in job:
        return 'Mid Level'
    else:
        return 'Entry Level'

norway_df1['experience_level'] = norway_df1.apply(
    lambda x: fill_exp(x['job_title']) if pd.isna(x['experience_level']) else x['experience_level'],
    axis=1
)

# %%
norway_df1
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 1    AI00021                Data Engineer     1409068             NOK
# 2    AI00054               Data Scientist     1419915             NOK
# 3    AI00062               Data Scientist     1704108             NOK
# 4    AI00073  Machine Learning Researcher     1310610             NOK
# ..       ...                          ...         ...             ...
# 716  AI14905           AI Product Manager     1185744             NOK
# 717  AI14918              ML Ops Engineer     2867056             NOK
# 718  AI14977                AI Consultant     1728510             NOK
# 719  AI14978           Research Scientist     3422664             NOK
# 720  AI14983                 Data Analyst      742570             NOK
#
#     experience_level employment_type company_location company_size  \
# ...

# %%
norway_df1['experience_level'] = norway_df1['experience_level'].fillna('Not Specified')

# %%
norway_df1['experience_level'].unique()
# Out:
# array(['Not Specified'], dtype=object)

# %%
norway_df_Data_Engineer =norway_df1[norway_df1['job_title'] == 'Data Engineer']

# %%
def set_experience(level):
    if level in ['', 'Senior', 'Sr', 'Lead']:
        return 'Senior Level'
    elif level in ['MI', 'Mid', 'Intermediate']:
        return 'Mid Level'
    elif level in ['EN', 'Entry', 'Junior', 'Fresher']:
        return 'Entry Level'
    elif level in ['EX', 'Executive', 'Director', 'Manager']:
        return 'Executive Level'
    else:
        return 'Not Specified'

# %%
norway_df1['experience_level_clean'] = norway_df1['experience_level'].apply(set_experience)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK    Not Specified
# 26   AI00453  Data Engineer     1683171             NOK    Not Specified
# 31   AI00560  Data Engineer     2721432             NOK    Not Specified
# 45   AI00800  Data Engineer     2977474             NOK    Not Specified
# 46   AI00817  Data Engineer     1661520             NOK    Not Specified
# 72   AI01266  Data Engineer     1407199             NOK    Not Specified
# 86   AI01576  Data Engineer     2340922             NOK    Not Specified
# 135  AI02755  Data Engineer     2217001             NOK    Not Specified
# 138  AI02793  Data Engineer     1024180             NOK    Not Specified
# 155  AI03158  Data Engineer     3215772             NOK    Not Specified
# 170  AI03546  Data Engineer     2587273             NOK    Not Specified
# 192  AI03929  Data Engineer     1940484             NOK    Not Specified
# ...

# %%
def set_exp_from_employment(emp_type):
    if emp_type == 'Contract':
        return 'Senior Level'
    elif emp_type == 'Freelance':
        return 'Executive Level'
    elif emp_type == 'Part Time':
        return 'Mid Level'
    elif emp_type == 'Full-Time' or emp_type == 'Full Time':
        return 'Entry Level'
    else:
        return 'Not Specified'

norway_df_Data_Engineer['experience_level'] = norway_df_Data_Engineer['employment_type'].apply(set_exp_from_employment)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['company_size'] = norway_df_Data_Engineer['company_size'].map({
    'M': "Mid-Size",
    'L': "Large Size",
    'S': "Small Size"
})

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['Company_name'] = norway_df_Data_Engineer['Company_name']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Company_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2341/3791473599.py in <cell line: 0>()
# ...

# %%
company_city_data = [
    ("Cognite", "Oslo"),
    ("Kahoot!", "Oslo"),
    ("Schibsted", "Oslo"),
    ("Telenor", "Fornebu"),
    ("DNB", "Oslo"),
    ("Equinor", "Stavanger"),
    ("Boost.ai", "Sandefjord"),
    ("Huddly", "Oslo"),
    ("No Isolation", "Oslo"),
    ("Xeneta", "Oslo"),
    ("Spacemaker AI", "Oslo"),
    ("Askeladden & Co", "Oslo"),
    ("Crayon", "Oslo"),
    ("Visma", "Oslo"),
    ("Computas", "Oslo"),
    ("Sopra Steria Norway", "Oslo"),
    ("Capgemini Norway", "Oslo"),
    ("Accenture Norway", "Oslo"),
    ("Tietoevry", "Oslo"),
    ("Bouvet", "Oslo"),
    ("Knowit", "Oslo"),
    ("Miles", "Bergen"),
    ("Bekk Consulting", "Oslo"),
    ("Itera", "Oslo"),
    ("Atea", "Oslo"),
    ("StormGeo", "Bergen"),
    ("Kongsberg Gruppen", "Kongsberg"),
    ("DIPS", "Bodø"),
]

# %%
import pandas as pd

df_companies = pd.DataFrame(company_city_data, columns=['Company_Name', 'City'])

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['Company_Name'] = df_companies['Company_Name']
norway_df_Data_Engineer['city'] = df_companies['City']

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
import random

norway_df_Data_Engineer['Company_Name'] = [
    random.choice(df_companies['Company_Name']) for _ in range(len(norway_df_Data_Engineer))
]

norway_df_Data_Engineer['city'] = [
    random.choice(df_companies['City']) for _ in range(len(norway_df_Data_Engineer))
]

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer = norway_df_Data_Engineer.drop('experience_level_clean', axis=1)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
ai_companies = [
    "Cognite",
    "Boost.ai",
    "Spacemaker AI",
    "Huddly",
    "No Isolation"
]

# %%
norway_df_Data_Engineer['Is_AI_Company'] = norway_df_Data_Engineer['Company_Name'].apply(
    lambda x: "Yes" if x in ai_companies else "No"
)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
company_type_map = {
    "Cognite": "Unicorn",
    "Kahoot!": "Unicorn",
    "Boost.ai": "Startup",
    "No Isolation": "Startup",
    "Huddly": "Product Based",
    "Xeneta": "Product Based",
    "Spacemaker AI": "Startup",

    "Telenor": "MNC",
    "Accenture Norway": "MNC",
    "Capgemini Norway": "MNC",
    "Tietoevry": "MNC",

    "DNB": "Fintech",
    "Equinor": "Enterprise",
    "Kongsberg Gruppen": "Enterprise",

    "Schibsted": "Product Based",
    "Visma": "Product Based",
    "Atea": "Enterprise",
    "Bouvet": "Enterprise"
}

# %%
norway_df_Data_Engineer['Company_Type'] = norway_df_Data_Engineer['Company_Name'].map(company_type_map)

# %%
norway_df_Data_Engineer['Company_Type'].fillna("Other", inplace=True)
# Out:
# /tmp/ipykernel_2341/2373611741.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   norway_df_Data_Engineer['Company_Type'].fillna("Other", inplace=True)

# %%
norway_df_Data_Engineer['Company_Type'] = norway_df_Data_Engineer['Company_Name'].apply(
    lambda x: company_type_map.get(str(x), "Other")
)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['Tax'] = norway_df_Data_Engineer['Salary_NOK'] * 0.30

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['In_Hand_Salary'] = norway_df_Data_Engineer['Salary_NOK'] - norway_df_Data_Engineer['Tax']

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['Description'] = norway_df_Data_Engineer['Company_Type'].apply(
    lambda x: "High Benefits + Stocks" if x in ['Unicorn', 'MNC'] else "Basic Benefits + Medical"
)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer['Description'] = """
Facilities: Flexible Work, Remote Options, Paid Leaves
Medical: Health Insurance, Mental Health Support
Stocks: ESOPs, Bonuses, Performance Incentives
"""

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
def skills_by_level(level):
    if level == 'Entry Level':
        return "Python, SQL, Basics of ML, Data Cleaning, Excel"

    elif level == 'Mid Level':
        return "Python, SQL, ETL Pipelines, Machine Learning, Cloud (AWS/GCP), Data Modeling"

    elif level == 'Senior Level':
        return "Advanced ML, Big Data (Spark), System Design, Data Architecture, Leadership"

    elif level == 'Executive Level':
        return "AI Strategy, Team Leadership, Business Intelligence, Decision Making, Stakeholder Management"

    else:
        return "General Skills"

norway_df_Data_Engineer['Skills'] = norway_df_Data_Engineer['experience_level'].apply(skills_by_level)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
norway_df_Data_Engineer.drop('Industry', axis=1, inplace=True)

# %%
norway_df_Data_Engineer
# Out:
#       job_id      job_title  Salary_NOK salary_currency experience_level  \
# 1    AI00021  Data Engineer     1409068             NOK      Entry Level
# 26   AI00453  Data Engineer     1683171             NOK        Mid Level
# 31   AI00560  Data Engineer     2721432             NOK  Executive Level
# 45   AI00800  Data Engineer     2977474             NOK      Entry Level
# 46   AI00817  Data Engineer     1661520             NOK        Mid Level
# 72   AI01266  Data Engineer     1407199             NOK      Entry Level
# 86   AI01576  Data Engineer     2340922             NOK     Senior Level
# 135  AI02755  Data Engineer     2217001             NOK      Entry Level
# 138  AI02793  Data Engineer     1024180             NOK      Entry Level
# 155  AI03158  Data Engineer     3215772             NOK     Senior Level
# 170  AI03546  Data Engineer     2587273             NOK        Mid Level
# 192  AI03929  Data Engineer     1940484             NOK  Executive Level
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2341/266510314.py in <cell line: 0>()
# ----> 1 job_title3
#
# NameError: name 'job_title3' is not defined

# %%
norway_df

# %%
norway_df1
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 1    AI00021                Data Engineer     1409068             NOK
# 2    AI00054               Data Scientist     1419915             NOK
# 3    AI00062               Data Scientist     1704108             NOK
# 4    AI00073  Machine Learning Researcher     1310610             NOK
# ..       ...                          ...         ...             ...
# 716  AI14905           AI Product Manager     1185744             NOK
# 717  AI14918              ML Ops Engineer     2867056             NOK
# 718  AI14977                AI Consultant     1728510             NOK
# 719  AI14978           Research Scientist     3422664             NOK
# 720  AI14983                 Data Analyst      742570             NOK
#
#     experience_level employment_type company_location company_size  \
# ...

# %%
norway_df1['job_title']
# Out:
# 0      Autonomous Systems Engineer
# 1                    Data Engineer
# 2                   Data Scientist
# 3                   Data Scientist
# 4      Machine Learning Researcher
#                   ...
# 716             AI Product Manager
# 717                ML Ops Engineer
# 718                  AI Consultant
# 719             Research Scientist
# 720                   Data Analyst
# Name: job_title, Length: 721, dtype: object

# %%
norway_df1[norway_df1['job_title'] == 'Autonomous Systems Engineer'].shape[0]
# Out:
# 37

# %%
norway_df1[norway_df1['job_title'].str.contains('Autonomous Systems Engineer', case=False, na=False)]
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
def set_exp_from_salary(salary):
    if salary < 500000:
        return 'Entry Level'
    elif salary < 1200000:
        return 'Mid Level'
    elif salary < 2500000:
        return 'Senior Level'
    else:
        return 'Executive Level'

# %%
autonomous_df = norway_df1[norway_df1['job_title'] == 'Autonomous Systems Engineer']

# %%
print(len(autonomous_df))
# Out:
# 37

# %%
autonomous_df.to_csv('autonomous_systems_jobs_norway.csv', index=False)

# %%
autonomous_df = norway_df1[norway_df1['job_title'].str.contains('Autonomous', case=False, na=False)]

# %%
print(autonomous_df['job_title'].tolist())
# Out:
# ['Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Autonomous Systems Engineer', 'Auto
# ...

# %%
print(type(norway_df1))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
import pandas as pd

norway_df1 = pd.read_csv('norway_autonumous.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_2341/798786981.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 norway_df1 = pd.read_csv('norway_autonumous.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
autonomous_df = norway_df1[
    norway_df1['job_title'].str.strip().str.lower() == 'autonomous systems engineer'
]

# %%
print(autonomous_df.shape)
print(autonomous_df.head())
# Out:
# (37, 15)
#      job_id                    job_title  Salary_NOK salary_currency  \
# 0   AI00014  Autonomous Systems Engineer      721980             NOK
# 59  AI01019  Autonomous Systems Engineer     1415746             NOK
# 84  AI01534  Autonomous Systems Engineer     2802964             NOK
# 97  AI01947  Autonomous Systems Engineer     1779456             NOK
# 98  AI01978  Autonomous Systems Engineer     1679244             NOK
#
#    experience_level employment_type company_location company_size  \
# 0     Not Specified        Contract           Norway            S
# 59    Not Specified       Freelance           Norway            S
# 84    Not Specified       Freelance           Norway            M
# 97    Not Specified       Freelance           Norway            L
# 98    Not Specified        Contract           Norway            S
#
#    employee_residence  remote_ratio  Company_Type  Industry  Is_AI_Company  \
# ...

# %%
Data_autonomous_df=autonomous_df.to_csv('autonomous_systems_engineer_jobs.csv', index=False)

# %%
print(autonomous_df)
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df.columns
# Out:
# Index(['job_id', 'job_title', 'Salary_NOK', 'salary_currency',
#        'experience_level', 'employment_type', 'company_location',
#        'company_size', 'employee_residence', 'remote_ratio', 'Company_Type',
#        'Industry', 'Is_AI_Company', 'Company_Name', 'experience_level_clean'],
#       dtype='object')

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
def set_exp_from_salary(salary):
    if salary < 1000000:
        return 'Entry Level'
    elif salary < 1800000:
        return 'Mid Level'
    elif salary < 2500000:
        return 'Senior Level'
    else:
        return 'Executive Level'

# Apply on dataframe
autonomous_df['experience_level'] = autonomous_df['Salary_NOK'].apply(set_exp_from_salary)
# Out:
# /tmp/ipykernel_2341/2816158953.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['experience_level'] = autonomous_df['Salary_NOK'].apply(set_exp_from_salary)

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
def set_employment_from_exp(exp):
    if exp == 'Entry Level':
        return 'Contract'
    elif exp == 'Mid Level':
        return 'Freelance'
    elif exp == 'Senior Level':
        return 'Full-Time'
    elif exp == 'Executive Level':
        return 'Full-Time'
    else:
        return 'Not Specified'

# Apply
autonomous_df['employment_type'] = autonomous_df['experience_level'].apply(set_employment_from_exp)
# Out:
# /tmp/ipykernel_2341/2728008276.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['employment_type'] = autonomous_df['experience_level'].apply(set_employment_from_exp)

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df['company_size'] = autonomous_df['company_size'].map({
    'M': "Mid-Size",
    'L': "Large Size",
    'S': "Small Size"
})
# Out:
# /tmp/ipykernel_2341/3252621449.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['company_size'] = autonomous_df['company_size'].map({

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df.drop('experience_level_clean', axis=1, inplace=True)
# Out:
# /tmp/ipykernel_2341/428139715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df.drop('experience_level_clean', axis=1, inplace=True)

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
company_type_map = {
    "Cognite": "Unicorn",
    "Kahoot!": "Unicorn",
    "Boost.ai": "Startup",
    "No Isolation": "Startup",
    "Huddly": "Product Based",
    "Xeneta": "Product Based",
    "Spacemaker AI": "Startup",

    "Telenor": "MNC",
    "Accenture Norway": "MNC",
    "Capgemini Norway": "MNC",
    "Tietoevry": "MNC",

    "DNB": "Fintech",
    "Equinor": "Enterprise",
    "Kongsberg Gruppen": "Enterprise",

    "Schibsted": "Product Based",
    "Visma": "Product Based",
    "Atea": "Enterprise",
    "Bouvet": "Enterprise"
}

# %%
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)
# Out:
# /tmp/ipykernel_2341/3477729993.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df['Company_Type'].fillna("Other", inplace=True)
# Out:
# /tmp/ipykernel_2341/222107625.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   norway_df_Data_Engineer['Company_Type'].fillna("Other", inplace=True)

# %%
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].apply(
    lambda x: company_type_map.get(str(x), "Other")
)
# Out:
# /tmp/ipykernel_2341/3520110734.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].apply(

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)
autonomous_df['Company_Type'].fillna("Other", inplace=True)
# Out:
# /tmp/ipykernel_2341/3844438029.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)
# /tmp/ipykernel_2341/3844438029.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].apply(
    lambda x: company_type_map.get(x, "Other")
)
# Out:
# /tmp/ipykernel_2341/1467771737.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].apply(

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
company_type_map = {
    "Cognite": "Unicorn",
    "Kahoot!": "Unicorn",
    "Boost.ai": "Startup",
    "No Isolation": "Startup",
    "Huddly": "Product Based",
    "Xeneta": "Product Based",
    "Spacemaker AI": "Startup",

    "Telenor": "MNC",
    "Accenture Norway": "MNC",
    "Capgemini Norway": "MNC",
    "Tietoevry": "MNC",

    "DNB": "Fintech",
    "Equinor": "Enterprise",
    "Kongsberg Gruppen": "Enterprise",

    "Schibsted": "Product Based",
    "Visma": "Product Based",
    "Atea": "Enterprise",
    "Bouvet": "Enterprise"
}

# %%
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)

norway_df_Data_Engineer['Company_Type'].fillna("Other", inplace=True)
# Out:
# /tmp/ipykernel_2341/431454974.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)

# %%
print(autonomous_df['Company_Name'].unique())
# Out:
# [nan]

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)

autonomous_df['Company_Type'].fillna("Other", inplace=True)
# Out:
# /tmp/ipykernel_2341/609259650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)
# /tmp/ipykernel_2341/609259650.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
# ...

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
import random

# Step 1: Fill Company_Name
companies = list(company_type_map.keys())

autonomous_df['Company_Name'] = autonomous_df['Company_Name'].apply(
    lambda x: random.choice(companies) if pd.isna(x) else x
)

# Step 2: Company_Type
autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)
autonomous_df['Company_Type'].fillna("Other", inplace=True)

# Step 3: AI Company
ai_companies = ["Cognite", "Boost.ai", "Huddly", "Spacemaker AI"]

autonomous_df['Is_AI_Company'] = autonomous_df['Company_Name'].apply(
    lambda x: "Yes" if x in ai_companies else "No"
)
# Out:
# /tmp/ipykernel_2341/3004965067.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Name'] = autonomous_df['Company_Name'].apply(
# /tmp/ipykernel_2341/3004965067.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Company_Type'] = autonomous_df['Company_Name'].map(company_type_map)
# /tmp/ipykernel_2341/3004965067.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df['Tax'] = autonomous_df['Salary_NOK'] * 0.30   # 30% tax
# Out:
# /tmp/ipykernel_2341/2589974164.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Tax'] = autonomous_df['Salary_NOK'] * 0.30   # 30% tax

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
autonomous_df['In_Hand'] = autonomous_df['Salary_NOK'] - autonomous_df['Tax']
# Out:
# /tmp/ipykernel_2341/3858194246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['In_Hand'] = autonomous_df['Salary_NOK'] - autonomous_df['Tax']

# %%
autonomous_df['Description'] = autonomous_df['Company_Type'].apply(lambda x:
    "High growth, Stock options, AI projects" if x == "Startup" else
    "Medical insurance, Job security, Work-life balance" if x == "MNC" else
    "Stock benefits, Bonus, Tech innovation" if x == "Product Based" else
    "Banking benefits, Insurance, Stability" if x == "Fintech" else
    "Government scale projects, Stability, Benefits"
)
# Out:
# /tmp/ipykernel_2341/2479695286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Description'] = autonomous_df['Company_Type'].apply(lambda x:

# %%
autonomous_df['Skill_Description'] = autonomous_df['experience_level'].apply(lambda x:
    "Python, SQL basics, ML fundamentals" if x == "Entry Level" else
    "Data pipelines, ML models, Cloud (AWS/GCP)" if x == "Mid Level" else
    "System design, AI architecture, Team handling" if x == "Senior Level" else
    "Leadership, Strategy, Business + Tech decisions"
)
# Out:
# /tmp/ipykernel_2341/1883502049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   autonomous_df['Skill_Description'] = autonomous_df['experience_level'].apply(lambda x:

# %%
autonomous_df
# Out:
#       job_id                    job_title  Salary_NOK salary_currency  \
# 0    AI00014  Autonomous Systems Engineer      721980             NOK
# 59   AI01019  Autonomous Systems Engineer     1415746             NOK
# 84   AI01534  Autonomous Systems Engineer     2802964             NOK
# 97   AI01947  Autonomous Systems Engineer     1779456             NOK
# 98   AI01978  Autonomous Systems Engineer     1679244             NOK
# 128  AI02559  Autonomous Systems Engineer     1495305             NOK
# 143  AI02882  Autonomous Systems Engineer     3224907             NOK
# 145  AI02917  Autonomous Systems Engineer     2248606             NOK
# 153  AI03097  Autonomous Systems Engineer     1153771             NOK
# 177  AI03655  Autonomous Systems Engineer     1107151             NOK
# 225  AI04825  Autonomous Systems Engineer     2046261             NOK
# 237  AI05056  Autonomous Systems Engineer     3506632             NOK
# ...

# %%
norway_df1['job_title']
# Out:
# 0      Autonomous Systems Engineer
# 1                    Data Engineer
# 2                   Data Scientist
# 3                   Data Scientist
# 4      Machine Learning Researcher
#                   ...
# 716             AI Product Manager
# 717                ML Ops Engineer
# 718                  AI Consultant
# 719             Research Scientist
# 720                   Data Analyst
# Name: job_title, Length: 721, dtype: object

# %%
norway_df1['job_title']
# Out:
# 0      Autonomous Systems Engineer
# 1                    Data Engineer
# 2                   Data Scientist
# 3                   Data Scientist
# 4      Machine Learning Researcher
#                   ...
# 716             AI Product Manager
# 717                ML Ops Engineer
# 718                  AI Consultant
# 719             Research Scientist
# 720                   Data Analyst
# Name: job_title, Length: 721, dtype: object

# %%
norway_df1['job_title']
# Out:
# 0      Autonomous Systems Engineer
# 1                    Data Engineer
# 2                   Data Scientist
# 3                   Data Scientist
# 4      Machine Learning Researcher
#                   ...
# 716             AI Product Manager
# 717                ML Ops Engineer
# 718                  AI Consultant
# 719             Research Scientist
# 720                   Data Analyst
# Name: job_title, Length: 721, dtype: object

# %%
norway_df_Data_Engineer = norway_df1[norway_df1['job_title'] == 'Data Scientist'].shape[0]

# %%
def set_exp_from_salary(salary):
    if salary < 500000:
        return 'Entry Level'
    elif salary < 1200000:
        return 'Mid Level'
    elif salary < 2500000:
        return 'Senior Level'
    else:
        return 'Executive Level'

# %%
norway_df_Data_Engineer
# Out:
# 30

# %%
norway_df_Data_Engineer.to_csv("norway_data_engineer.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2341/2735692873.py in <cell line: 0>()
# ----> 1 norway_df_Data_Engineer.to_csv("norway_data_engineer.csv", index=False)
#
# AttributeError: 'int' object has no attribute 'to_csv'

# %%
norway_df_Data_Engineer = norway_df1[norway_df1['job_title'] == 'Data Scientist'].shape[0]

# %%
norway_df_Data_Engineer = norway_df1[norway_df1['job_title'] == 'Data Scientist']

norway_df_Data_Engineer.to_csv("norway_data_engineer.csv", index=False)

# %%
df_filtered = norway_df1[norway_df1['job_title'] == 'Data Scientist']

count = df_filtered.shape[0]
print("Total Data Scientists:", count)

df_filtered.to_csv("norway_data_engineer.csv", index=False)
# Out:
# Total Data Scientists: 30

# %%
df_filtered
# Out:
#       job_id       job_title  Salary_NOK salary_currency experience_level  \
# 2    AI00054  Data Scientist     1419915             NOK    Not Specified
# 3    AI00062  Data Scientist     1704108             NOK    Not Specified
# 48   AI00854  Data Scientist     1166203             NOK    Not Specified
# 67   AI01171  Data Scientist     1495053             NOK    Not Specified
# 69   AI01219  Data Scientist     1289043             NOK    Not Specified
# 77   AI01379  Data Scientist     1172556             NOK    Not Specified
# 78   AI01380  Data Scientist     1437555             NOK    Not Specified
# 114  AI02320  Data Scientist     2253646             NOK    Not Specified
# 160  AI03267  Data Scientist      958450             NOK    Not Specified
# 163  AI03348  Data Scientist     2324889             NOK    Not Specified
# 182  AI03728  Data Scientist     1281651             NOK    Not Specified
# 189  AI03894  Data Scientist      917826             NOK    Not Specified
# ...

# %%
def set_exp_from_employment_inr(salary):
  if salary < 900000:
    return "Entry Level"
  elif salary < 1500000:
    return  "mid Level"
  elif salary < 3000000:
    return "Senior Level"
  else:
    return "Exceutive Level"

# %%
df_filtered
# Out:
#       job_id       job_title  Salary_NOK salary_currency experience_level  \
# 2    AI00054  Data Scientist     1419915             NOK    Not Specified
# 3    AI00062  Data Scientist     1704108             NOK    Not Specified
# 48   AI00854  Data Scientist     1166203             NOK    Not Specified
# 67   AI01171  Data Scientist     1495053             NOK    Not Specified
# 69   AI01219  Data Scientist     1289043             NOK    Not Specified
# 77   AI01379  Data Scientist     1172556             NOK    Not Specified
# 78   AI01380  Data Scientist     1437555             NOK    Not Specified
# 114  AI02320  Data Scientist     2253646             NOK    Not Specified
# 160  AI03267  Data Scientist      958450             NOK    Not Specified
# 163  AI03348  Data Scientist     2324889             NOK    Not Specified
# 182  AI03728  Data Scientist     1281651             NOK    Not Specified
# 189  AI03894  Data Scientist      917826             NOK    Not Specified
# ...

# %%
df_filtered['experience_level'] = df_filtered['Salary_NOK'].apply(set_exp_from_employment_inr)

# %%
df_filtered
# Out:
#       job_id       job_title  Salary_NOK salary_currency experience_level  \
# 2    AI00054  Data Scientist     1419915             NOK        mid Level
# 3    AI00062  Data Scientist     1704108             NOK     Senior Level
# 48   AI00854  Data Scientist     1166203             NOK        mid Level
# 67   AI01171  Data Scientist     1495053             NOK        mid Level
# 69   AI01219  Data Scientist     1289043             NOK        mid Level
# 77   AI01379  Data Scientist     1172556             NOK        mid Level
# 78   AI01380  Data Scientist     1437555             NOK        mid Level
# 114  AI02320  Data Scientist     2253646             NOK     Senior Level
# 160  AI03267  Data Scientist      958450             NOK        mid Level
# 163  AI03348  Data Scientist     2324889             NOK     Senior Level
# 182  AI03728  Data Scientist     1281651             NOK        mid Level
# 189  AI03894  Data Scientist      917826             NOK        mid Level
# ...

# %%
def set_employment_from_exp(exp):
    if exp == 'Entry Level':
        return 'Intern'

    elif exp == 'mid Level':
        return 'Full-Time'

    elif exp == 'Senior Level':
        return 'Full-Time'

    elif exp == 'Executive Level':
        return 'Contract'

    else:
        return 'Not Specified'

# %%
df_filtered['employment_type'] = df_filtered['experience_level'].apply(set_employment_from_exp)

# %%
df_filtered
# Out:
#       job_id       job_title  Salary_NOK salary_currency experience_level  \
# 2    AI00054  Data Scientist     1419915             NOK        mid Level
# 3    AI00062  Data Scientist     1704108             NOK     Senior Level
# 48   AI00854  Data Scientist     1166203             NOK        mid Level
# 67   AI01171  Data Scientist     1495053             NOK        mid Level
# 69   AI01219  Data Scientist     1289043             NOK        mid Level
# 77   AI01379  Data Scientist     1172556             NOK        mid Level
# 78   AI01380  Data Scientist     1437555             NOK        mid Level
# 114  AI02320  Data Scientist     2253646             NOK     Senior Level
# 160  AI03267  Data Scientist      958450             NOK        mid Level
# 163  AI03348  Data Scientist     2324889             NOK     Senior Level
# 182  AI03728  Data Scientist     1281651             NOK        mid Level
# 189  AI03894  Data Scientist      917826             NOK        mid Level
# ...
